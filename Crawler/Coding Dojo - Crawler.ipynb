# %% [markdown]
# # ☯ Coding Dojo ☯

# %% [markdown]
# <img style="float:left" src="imgs/vamos_coletar.png">
# ## Regras
#
# Ponto de participação, poderá perdido se:
#
#     - Aluno atrasado (ver política de atraso na especificação)
#     - Recusar participação como piloto/copiloto
#         - Ou não querer sair do computador, quando solicitado :-)
#     - Demorar para sair quando solicitado
#     - Parar de participar por:
#         - Uso de outro computador
#         - Uso de celular
#         - Usar a internet
#         - Conversa

# %% [markdown]
# Antes de entregar, certifique-se que tenha executado todos os comandos/códigos deste Jupyter. É obrigatório que todas as saídas tenham sido apresentadas. Perda de 3 pontos caso não tenham feito isso.

# %% [markdown]
# # Dependencias

# %% [markdown]
# Se necessário, instale o python3 e o pip3 abaixo usando `sudo apt-get install python3 python3-pip`.  Execute abaixo para instalar o [BeautifulSoup](https://www.crummy.com/software/BeautifulSoup/) e o [lxml](https://lxml.de/). Qualquer linha de comando/código como a de baixo, você pode executá-la a selecionando e pressionando `ctrl+enter` ❣️.

# %%
# !pip3 install bs4
# !pip3 install lxml

# %% [markdown]
# Caso de comando não encontrado `pip3` use `pip`.

# %% [markdown]
# # Coletor

# %% [markdown]
# <img src="imgs/arquitetura_coletor.png">

# %% [markdown]
# Você deverá completar a implementação das três classes abaixo para fazer o coletor: `Domain`, `Scheduler` e `PageFetcher`. Conforme figura acima, o `Scheduler` é responsável por armazenar as filas de URLs a serem requisitadas; o PageFetcher serão *threads* responsáveis por fazer as requisições das URLs obtidas por meio do escalonador (instancia da classe `Scheduler`). A classe `Domain` armazena informações importantes sobre o servidor a serem usadas no momento do escalonamento das URLs.

# %% [markdown]
# ## Classe `Domain`

# %% [markdown]
# <figure style="text-align:center">
#     <img src="imgs/estrutura_coletor.png">
#     <caption>Fonte: Baeza-Yates e Ribeiro-Neto, 2011 </caption>
# </figure>

# %% [markdown]
# Antes de começar a fazer o escalonador (classe `Scheduler`) devemos implementar a classe que representa os domínios. Conforme visto na figura acima, o escalonador possuirá diversas filas, uma para cada servidor.  Em nosso caso, o servidor será um domínio - que você irá implementar na classe `Domain` do arquivo `domain.py`.
#
# O escalonador percorrerá cada servidor e obterá o primeiro da fila do primeiro servidor acessível. O servidor é acessível obdecendo o limite de tempo entre requisições (em segundos, usando o atributo `time_limit_between_requests`).
#
# Nesta atividade você irá implementar a classe `Domain`, que já possui os seguintes atributos:
#
# - *time_limit_between_requests*: Limite entre requisições (int)
# - *nam_domain*: Nome do domínio (String)
# - *time_last_access*: [Objeto Datetime](https://docs.python.org/3/library/datetime.html#datetime-objects) informando da data/hora do último acesso
#
# O prefixo da variável sempre irá denotar o tipo da mesma.

# %% [markdown]
# **Atividade 1 - classe `Domain`**: Complete a classe `Domain` implementando os métodos/atributos calculados descritos a seguir. Logo após, execute o ❣️ teste unitário ❣️ para verificar se os métodos/atributos calculados foram implementados conforme esperado.
#
# - **accessed_now**: Método que modifica o último acesso com a data/hora atual usando um [objeto datetime](https://docs.python.org/3/library/datetime.html#datetime-objects)
# - **time_since_last_access**: Atributo calculado que retorna um [objeto TimeDelta](https://docs.python.org/3/library/datetime.html#timedelta-objects) com a diferença da data atual e a data do último acesso. Veja os exemplos de uso do TimeDelta na sua documentação
# - **is_accessible**: Método que verdadeiro se o domínio estiver acessível

# %% [markdown]
# Os métodos `count_fetched_page` e `has_finished_crawl` já estão implementados. Execute o teste unitário a seguir. Veja que o comando abaixo executa o teste unitário presente no arquivo `crawler/scheduler_test.py`. Analise-o para entender como implementamos testes unitários.

# %%
# !python -m crawler.scheduler_test DomainTest.test_domain
# Out:
# Verificando acesso a um dominio já requisitado (após espera)
# aguardando 10 segundos...
# .
# ----------------------------------------------------------------------
# Ran 1 test in 10.000s
#
# OK

# %% [markdown]
# **Atividade 2 - métodos `__hash__` e `__eq__` da classe `Domain`**: A fila será implementada por um dicionario ordenado ([OrderedDict](https://docs.python.org/2/library/collections.html#collections.OrderedDict)) em que a chave será um objeto da classe domínio e o valor serão uma lista de URLs. Para que seja possível a busca do domínio, você deverá implementar os métodos `__hash__` e `__eq__` de forma similar ao seguinte exemplo:

# %%
from collections import OrderedDict
class Xuxu():
    def __str__(self):
        return "xuxuuu"
    
    def __hash__(self):
        return hash("xuxu")
    def __eq__(self, x):
        return x == "xuxu"
d = OrderedDict()
d[Xuxu()] = 'A'
print("xuxu" in d)

# %% [markdown]
# No nosso caso, deve ser permitido fazer a busca no dicionário pelo nome do domínio ou pelo objeto, ou seja, após a implementação desta atividade, o seguinte código irá funcionar corretamente:

# %%
from crawler.domain import Domain
from collections import OrderedDict

obj_domain = Domain("oi.com",10)
dic_x = OrderedDict()
dic_x[obj_domain] = "lala"
dic_x["oi.com"] = "oi"

#abaixo, em ambos os casos, será encontrado/impresso a string "oi"
print(dic_x["oi.com"])
print(dic_x[obj_domain])
# Out:
# oi
# oi

# %% [markdown]
# Lembre-se que, em nosso caso, o parametro do método `__eq__` pode ser um objeto da classe `Domain` ou uma string representando o nome do domínio. Caso faça alguma modificação no código, você deverá reiniciar o kernel para que o efeito seja visto no código acima (para reiniciar, clique em Kernel->Restart). Isso ocorre que, uma vez dado import em um módulo, esse modulo não é alterado no Jupyter caso você faça uma modificação no código.

# %% [markdown]
# ## Classe `Scheduler`

# %% [markdown]
# Agora você irá implementar o escalonador. Essa classe será responsável por gerir as URLs.
# Para isso, será implementado as filas por servidores conforme apresentado na figura da seção anterior.
# Para isso, utilizaremos um OrderedDict em que as chaves são os servidores (objeto da classe `Domain`) e o valor será uma lista de tuplas com as URLs e sua profundidade. Com o objetivo de armazenar as URLs de forma estruturada, as mesmas **não serão** string, ao invés disso, serão objetos da classe `ParseResult` - essa classe é retornada do método [urlparse](https://docs.python.org/3/library/urllib.parse.html). Veja um exemplo abaixo.

# %%
from crawler.domain import Domain
from crawler.scheduler import Scheduler
from urllib.parse import urlparse

dict_filas_por_servidor = {Domain("www.globo.com",10):[
                                                (urlparse("http://www.globo.com/esporte"),1),
                                                (urlparse("http://www.globo.com/noticia_um"),2),
                                                (urlparse("http://www.globo.com/noticia_dois"),3),
                                                (urlparse("http://www.globo.com/noticia_tres"),3),
                                                ],
                            Domain("www.cnpq.br",10):[(urlparse("http://www.cnpq.br/pesquisadores"),1),
                                               (urlparse("http://www.cnpq.br/bolsas"),1)]
                          }

# %% [markdown]
# Assim, a classe `Scheduler`, no arquivo `scheduler.py` possui os seguintes atributos:
#
# - `str_usr_agent`: Nome do `User agent`. Usualmente, é o nome do navegador, no nosso caso, será o nome do coletor (usualmente, terminado em `bot`)
# - `page_limit`: Número de páginas a serem coletadas
# - `depth_limit`: Profundidade máxima a ser coletada
# - `page_count`: Quantidade de páginas já coletadas
# - `dic_url_per_domain`: Fila de URLs por domínio (explicado anteriormente)
# - `set_discovered_urls`: Conjunto de URLs descobertas, ou seja, que foi extraída em algum HTML e já adicionadas na fila - mesmo se já ela foi retirada da fila. A URL armazenada deve ser uma string.
# - `dic_robots_per_domain`: Dicionário armazenando, para cada domínio, o objeto representando as regras obtidas no `robots.txt`

# %% [markdown]
# **Atividad 3 - Método `can_add_page`**: Esse método irá retornar verdadeiro caso seja possível adicionar a página `obj_url` (objeto da classe ParseResult) que foi coletada na profundidade `depth`. Para que seja possível adicionar na lista, esta pagina não deve ter sido descoberta e nem com a profundidade maior que o limite. Este método será testado por teste unitário apenas após a implementação da adição e obtenção das URLs.

# %% [markdown]
# **Atividade 4 método `add_new_page` - Adicionar nova página**:  Este método retorna falso caso não seja possível adicionar a página (por meio do método `can_add_page`) e verdadeiro, caso contrário. Caso seja possível, deve-se adicionar a url `obj_url` na fila `dic_url_per_domain`. Lembre-se da estrutura do dicionário `dic_url_per_domain`. Não esqueça de armazenar que esta URL já foi descoberta. Este método será testado por teste unitário apenas após a implementação da obtenção das URLs. Lembre-se de como trabalhar com [dicionários](https://daniel-hasan.github.io/cefet-web-grad/classes/python2/#mais-colecoes)

# %% [markdown]
# **Atividade 5 método `get_next_url` - obtém a próxima URL da fila**: Este método retona uma tupla `url,profundade` da próxima URL a ser coletada por meio da fila `dic_url_per_domain` retirando este item da fila. Lembre-se que:
#
# - Ele deverá retornar a primeira URL do primeiro servidor que estiver acessível.
# - Você deve indicar que o servidor foi acessado
# - Caso a fila deste servidor esteja vazia, elimine-o do dicionário
# - Caso não encontre a URL, [coloque a Thread para esperar](https://docs.python.org/2/library/time.html#time.sleep) e, logo após, procure novamente
#
# Logo após, você já pode executar o teste unitário para verificar se a obtenção e adição de URLs está correta. Caso haja algum problema, existem já alguns prints comentados no código, descomente-os para verificar se o fluxo está ocorrendo da forma correta. Você deverá entregar sem a exibição desses prints (caso contrário, perderá pontos).

# %%
# !python -m crawler.scheduler_test SchedulerTest.test_add_remove_page
# Out:
# Verificação da ordem das URLs...
# Resgatando a segunda página do mesmo dominio...
# Tempo esperado: 20 segundos
# .
# ----------------------------------------------------------------------
# Ran 1 test in 20.001s
#
# OK

# %% [markdown]
# **Atividade 6 método `can_fetch_page`**: Este método deve retornar verdadeiro caso a url (Objeto `ParseResult`), passada como parâmetro, pode ser coletada de acordo com o `Robots.txt` do domínio. Para isso, você deve usar o [`RobotFileParser`](https://docs.python.org/3/library/urllib.robotparser.html) para requisitar a URL do `robots.txt` deste domínio. Por razões de performance, você só poderá requisitar o robots.txt uma única vez por domínio. Assim, use o `dic_robots_per_domain` apropriadamente. Execute o teste unitário abaixo para verificar seu funcionamento.

# %%
# !python -m crawler.scheduler_test SchedulerTest.test_can_fetch
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.328s
#
# OK

# %% [markdown]
# **Atividade 7 - Inicialização das sementes no construtor**: No construtor da classe `Scheduler` você deve adicionar as páginas sementes na fila. Tais sementes são passadas pelo parametro `arr_urls_seeds` do construtor.

# %%
# !python -m crawler.scheduler_test SchedulerTest.test_init
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.000s
#
# OK

# %% [markdown]
# Logo após, utize a anotação @synchronized aonde julgar necessário para transformar em ThreadSafe.

# %% [markdown]
# ## PageFetcher

# %% [markdown]
# **Atividade 8 - Efetuar a requisição - método `request_url`:** Neste método você irá fazer a requisição usando a api [requests](https://requests.readthedocs.io/en/master/). Além disso, deve-se informar no cabeçalho (em `User-Agent`) o nome do coletor. O método deverá retornar o conteúdo (em binário) apenas se o conteúdo for HTML (ver no cabeçalho da resposta o tipo do conteúdo). Caso não seja, ele deverá retornar `None`.

# %%
# !python -m crawler.page_fetcher_test PageFetcherTest.test_request_url
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 22.090s
#
# OK

# %% [markdown]
# **Atividade 9 extração das URLs por meio do método `discover_links`**: A partir do conteúdo (texto em binário) `bin_str_content` deve-se extrair seus os links. O conteúdo esta em binário, pois, o BeautifulSoup, internamente, verifica o encoding por meio da [tag meta](https://www.w3schools.com/tags/att_meta_charset.asp) e converte para UTF8. A URL da página coletada é um objeto ParseResult `obj_url` que está na profundidade `depth`.
#
# Para cada URL extraída, você deverá retornar uma tupla com a URL (objeto ParseResult) e a sua profundidade. Utilize o comando `yield` para retornar essas tuplas. A profundidade é calculada de por meio de  `obj_url` e `depth`, conforme comentado em sala de aula.
#
# Para a extração dos links, use o [CSS Selector do BeautifulSoup](https://www.crummy.com/software/BeautifulSoup/bs4/doc/#css-selectors). Seletor CSS é uma expressão que define quais elementos HTML serão estilizados pelo CSS. No *Beatifulsoup* eles são usados para selecionar quais tags serão extraídas. Veja o exemplo de uso e brinque abaixo. Caso precise, veja aqui um pouco de seletores CSS: [slides de Web](https://fegemo.github.io/cefet-front-end/classes/css2/#outros-seletores), [documentação MDN](https://developer.mozilla.org/en-US/docs/Web/CSS/CSS_Selectors).

# %%
from bs4 import BeautifulSoup

# %%
# !python -m crawler.page_fetcher_test PageFetcherTest.test_discover_links
# Out:
# Simulação da extração de links da página http://www.pudim.com.br na profundidade nível 2...
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.002s
#
# OK

# %% [markdown]
# **Atividade 10 - método que solicita uma nova URL**: Por meio do método `crawl_new_url` você deverá utilizar os métodos previamente implementados para:
#
# - Solicitar ao escalonador uma nova URL
# - Fazer a requisição e obter o resultado (em binário)
# - Caso a URL seja um HTML válido, imprima esta URL e extraia os seus links

# %% [markdown]
# **Atividade 11 - método run**: Este método deve coletar páginas enquanto a coleta não foi finalizada

# %% [markdown]
# **Atividade 12 - um pequeno teste para finalizar:** Use as sementes do seu grupo e crie abaixo um escalonador e 5 PageFetchers para extrair 30 páginas. Imprima também o tempo gasto total.

# %%
import time
from urllib.parse import urlparse

from crawler import page_fetcher, scheduler

def test_crawler():
  usr_agent = "crawler-bot"
  depth_limit = 5
  page_limit = 30
  webpage_seeds = [
                    'http://www.globo.com',
                    'http://www.cnpq.br', 
                    'http://www.uol.com.br', 
                    'https://www.uai.com.br', 
                    'https://www.terra.com.br', 
                    'https://www.bbc.com', 
                    'https://www.tecmundo.com.br', 
                    'https://www.olhardigital.com.br',
                    'https://www.estadao.com.br', 
                    'https://www.em.com.br',
                    'https://www.gazetadopovo.com.br',
                    'https://www.correiobraziliense.com.br',
                  ]
  parsed_webpage_seeds = [urlparse(url) for url in webpage_seeds]

  obj_scheduler = scheduler.Scheduler(usr_agent, page_limit, depth_limit, parsed_webpage_seeds)


  page_fetcher_num = 5
  obj_process = []
  for i in range(page_fetcher_num):
    obj_process.append(page_fetcher.PageFetcher(obj_scheduler))
    obj_process[i].start()

  for p in obj_process:
    p.join()

  print("Fim da coleta")
  print("Quantidade de páginas coletadas: ", obj_scheduler.page_count)
  print("Quantidade de URLS: ", len(obj_scheduler.set_discovered_urls))


if __name__ == '__main__':
  start = time.time()
  test_crawler()
  end = time.time()
  print("Tempo total: ", end - start)
# Out:
# URL: http://www.globo.com
# Link: https://www.globo.com/
# Link: https://minhaconta.globo.com
# Link: https://minhaconta.globo.com
# Link: https://g1.globo.com/?utm_source=globo.com&utm_medium=menuburguer
# Link: https://oglobo.globo.com/?utm_source=globo.com&utm_medium=menuburguer
# Link: https://valor.globo.com/?utm_source=globo.com&utm_medium=menuburguer
# Link: https://globoesporte.globo.com/?utm_source=globo.com&utm_medium=menuburguer
# Link: https://ge.globo.com/cartola/?utm_source=globocom&utm_medium=menuburguer&utm_campaign=c2022_10_cartola_cartola-2022_alcance&utm_content=MEN_cartola-2022
# Link: https://vitrine.globo.com/assine/globoplay-canais?origemId=1760&utm_source=gcom&utm_medium=menuburguer&utm_campaign=gcom-logo-menu
# Link: https://gshow.globo.com/?utm_source=globo.com&utm_medium=menuburguer
# Link: https://revistaquem.globo.com/?utm_source=globo.com&utm_medium=menuburguer
# Link: https://receitas.globo.com/?utm_source=globo.com&utm_medium=menuburguer
# Link: https://gigagloob.globo.com/assine/?origemId=2642&utm_source=globo.com&utm_medium=menuburguer
# Link: https://g1.globo.com/previsao-do-tempo?utm_source=globo.com&utm_medium=menu&utm_campaign=previsao-do-tempo
# Link: https://vitrine.globo.com/?origemId=1984&?utm_source=globo.com&utm_medium=menu
# Link: https://globoplay.globo.com/podcasts/categorias/podcasts-mais-ouvidos/?origemId=1760&utm_source=gcom&utm_medium=menuburguer&utm_campaign=gcom-logo-menu-podcast
# Link: https://globoesporte.globo.com/futebol/times/flamengo/
# Link: https://globoesporte.globo.com/futebol/times/corinthians/
# Link: https://globoesporte.globo.com/rs/futebol/times/gremio/
# Link: https://globoesporte.globo.com/futebol/times/palmeiras/
# Link: https://globoesporte.globo.com/sp/santos-e-regiao/futebol/times/santos/
# Link: https://globoesporte.globo.com/futebol/times/sao-paulo/
# Link: https://globoesporte.globo.com/futebol/times/atletico-mg/
# Link: https://globoesporte.globo.com/futebol/times/fluminense/
# Link: https://globoesporte.globo.com/futebol/times/vasco/
# Link: https://globoesporte.globo.com/futebol/times/botafogo/
# Link: https://globoesporte.globo.com/futebol/times/cruzeiro/
# Link: https://globoesporte.globo.com/rs/futebol/times/internacional/
# Link: https://globoesporte.globo.com/pr/futebol/times/athletico-pr/
# Link: https://globoesporte.globo.com/sc/futebol/times/chapecoense/
# Link: https://globoesporte.globo.com/sp/vale-do-paraiba-regiao/futebol/times/bragantino/
# Link: https://globoesporte.globo.com/ce/futebol/times/ceara/
# Link: https://globoesporte.globo.com/pe/futebol/times/sport/
# Link: https://globoesporte.globo.com/ba/futebol/times/bahia/
# Link: https://globoesporte.globo.com/ce/futebol/times/fortaleza/
# Link: https://globoesporte.globo.com/futebol/times/america-mg/
# Link: https://globoesporte.globo.com/go/futebol/times/atletico-go/
# Link: https://globoesporte.globo.com/mt/futebol/times/cuiaba/
# Link: https://globoesporte.globo.com/rs/futebol/times/juventude/
# Link: https://globoesporte.globo.com/futebol/selecao-brasileira/
# Link: https://globoesporte.globo.com/futebol/brasileirao-serie-a/
# Link: https://globoesporte.globo.com/futebol/brasileirao-serie-b/
# Link: https://globoesporte.globo.com/futebol/copa-america/
# Link: https://globoesporte.globo.com/futebol/copa-do-brasil/
# Link: https://globoesporte.globo.com/futebol/copa-sul-americana/
# Link: https://globoesporte.globo.com/futebol/libertadores/
# Link: http://app.globoesporte.globo.com/futebol/publico-no-brasil/index.html
# Link: https://interativos.globoesporte.globo.com/futebol/rotatividade-dos-tecnicos
# Link: https://interativos.globoesporte.globo.com/futebol/mercado/vai-e-vem/vai-e-vem-do-mercado-2020
# Link: https://g1.globo.com/especiais/guia-de-compras/?utm_source=globo.com&utm_medium=menu
# Link: http://especiais.g1.globo.com/educacao/app-g1-enem/
# Link: https://g1.globo.com/educacao/enem/2020/
# Link: https://valorinveste.globo.com/ferramentas/calculadoras/calculadora-salario-liquido/?utm_source=globocom&utm_medium=referral&utm_campaign=menulateral-globocom
# Link: https://valorinveste.globo.com/ferramentas/comparador-de-investimentos/?utm_source=globocom&utm_medium=referral&utm_campaign=menulateral-globocom
# Link: https://g1.globo.com/loterias/
# Link: http://especiais.g1.globo.com/newsletter/
# Link: https://www.techtudo.com.br/mobile/
# Link: https://www.techtudo.com.br/eletronicos/tvs/
# Link: https://www.techtudo.com.br/informatica/notebooks/
# Link: https://www.techtudo.com.br/jogos/
# Link: https://www.techtudo.com.br/e-sports/
# Link: https://www.techtudo.com.br/softwares/apps/
# Link: https://www.techtudo.com.br/softwares/apps/redes-sociais/
# Link: https://www.techtudo.com.br/dicas-e-tutoriais/
# Link: https://www.techtudo.com.br/reviews/
# Link: https://www.techtudo.com.br/listas/
# Link: https://www.techtudo.com.br/playlist/videos-techtudo/
# Link: https://forum.techtudo.globo.com/
# Link: https://autoesporte.globo.com/
# Link: https://g1.globo.com/?utm_source=globo.com&utm_medium=menuburguer
# Link: https://extra.globo.com/
# Link: https://oglobo.globo.com/
# Link: https://valor.globo.com
# Link: https://valorinveste.globo.com/?utm_source=globocom&utm_medium=referral&utm_campaign=menulateral-globocom
# Link: http://revistaepoca.globo.com/
# Link: http://epocanegocios.globo.com/
# Link: http://revistagalileu.globo.com/
# Link: https://globorural.globo.com/
# Link: http://revistapegn.globo.com/
# Link: https://umsoplaneta.globo.com/
# Link: https://bhfm.globo.com/
# Link: https://cbn.globoradio.globo.com
# Link: https://radioglobo.globo.com/
# Link: http://revistacasaejardim.globo.com/
# Link: http://casavogue.globo.com/
# Link: http://revistacrescer.globo.com/
# Link: http://revistaglamour.globo.com/
# Link: http://gq.globo.com/
# Link: http://revistamarieclaire.globo.com/
# Link: http://revistamonet.globo.com/
# Link: http://revistaquem.globo.com/
# Link: https://vidadebicho.globo.com/
# Link: http://vogue.globo.com/
# Link: https://gshow.globo.com/novelas/alem-da-ilusao/
# Link: https://gshow.globo.com/novelas/quanto-mais-vida-melhor/
# Link: https://gshow.globo.com/novelas/um-lugar-ao-sol/
# Link: https://gshow.globo.com/realities/the-voice-mais/
# Link: https://gshow.globo.com/realities/the-masked-singer-brasil/
# Link: http://g1.globo.com/hora1
# Link: http://g1.globo.com/bom-dia-brasil/
# Link: http://g1.globo.com/jornal-hoje/
# Link: http://g1.globo.com/jornal-nacional/
# Link: http://g1.globo.com/jornal-da-globo/
# Link: http://g1.globo.com/globo-reporter/
# Link: http://fantastico.globo.com/
# Link: https://redeglobo.globo.com/
# Link: https://globoplay.globo.com/canais/bis/
# Link: https://globoplay.globo.com/canais/canal-brasil/
# Link: https://globoplay.globo.com/canais/canal-off/
# Link: https://globoesporte.globo.com/combate/
# Link: https://globoplay.globo.com/canais/futura/
# Link: https://g1.globo.com/globonews/
# Link: http://mundogloob.globo.com/
# Link: https://globoplay.globo.com/canais/gloobinho/
# Link: https://gnt.globo.com/
# Link: https://globoplay.globo.com/canais/modo-viagem/
# Link: https://globoplay.globo.com/canais/megapix/
# Link: https://multishow.globo.com/
# Link: https://globoesporte.globo.com/loja/premiere/?origemId=954
# Link: https://globoesporte.globo.com/sportv/
# Link: https://www.telecineplay.com.br/
# Link: https://globoplay.globo.com/canais/universal/
# Link: https://globoplay.globo.com/canais/viva/
# Link: http://somos.globo.com
# Link: https://memoriaglobo.globo.com/
# Link: https://historia.globo.com/
# Link: http://grupoglobo.globo.com/
# Link: http://g1.globo.com/principios-editoriais-do-grupo-globo.html
# Link: https://vitrine.globo.com/?origemId=2528&utm_source=globo.com&utm_medium=header&utm_campaign=vitrine
# Link: https://vitrine.globo.com/?origemId=2528&utm_source=globo.com&utm_medium=header&utm_campaign=vitrine-tooltip
# Link: #
# Link: #
# Link: #
# Link: https://minhaconta.globo.com
# Link: #
# Link: #
# Link: https://g1.globo.com/?utm_source=globo.com&utm_medium=header
# Link: https://globoesporte.globo.com/?utm_source=globo.com&utm_medium=header
# Link: https://gshow.globo.com/?utm_source=globo.com&utm_medium=header
# Link: https://globoplay.globo.com/?origemId=1760&utm_source=gcom&utm_medium=home&utm_campaign=gcom-botao-destaque-superior
# Link: https://oglobo.globo.com/?utm_source=globo.com&utm_medium=header&utm_campaign=chamada_header
# Link: https://g1.globo.com/?utm_source=globo.com&utm_medium=header
# Link: https://oglobo.globo.com/?utm_source=globo.com&utm_medium=header&utm_campaign=chamada_header
# Link: https://valor.globo.com/?utm_source=globo.com&utm_medium=header
# Link: https://globoesporte.globo.com/?utm_source=globo.com&utm_medium=header
# Link: https://ge.globo.com/cartola/?utm_source=globocom&utm_medium=header&utm_campaign=c2022_10_cartola_cartola-2022_alcance&utm_content=HEA_cartola-2022
# Link: https://globoplay.globo.com/?origemId=1760&utm_source=gcom&utm_medium=home&utm_campaign=gcom-botao-destaque-superior
# Link: https://gshow.globo.com/?utm_source=globo.com&utm_medium=header
# Link: https://revistaquem.globo.com/?utm_source=globo.com&utm_medium=header
# Link: https://receitas.globo.com/?utm_source=globo.com&utm_medium=header
# Link: https://gigagloob.globo.com/assine/?origemId=2641&utm_source=globo.com&utm_medium=header
# Link: https://g1.globo.com/politica/blog/andreia-sadi/post/2023/03/08/exclusivo-video-tentativa-governo-bolsonaro-joias.ghtml
# Link: https://valor.globo.com/politica/noticia/2023/03/08/bolsonaro-confirma-que-ficou-com-parte-das-joias-saudistas-que-entraram-de-forma-irregular-no-pais.ghtml
# Link: https://oglobo.globo.com/politica/noticia/2023/03/ex-secretario-do-governo-bolsonaro-vai-devolver-relogio-de-luxo-recebido-do-catar.ghtml?utm_source=globo.com&utm_medium=oglobo
# Link: https://ge.globo.com/futebol/times/flamengo/noticia/2023/03/08/pedro-e-relacionado-para-decisao-da-taca-guanabara-entre-flamengo-e-fluminense.ghtml
# Link: https://ge.globo.com/futebol/times/flamengo/noticia/2023/03/08/flamengo-faz-acordo-com-xara-de-joao-gomes-para-recuperar-dinheiro-de-transferencia-equivocada.ghtml
# Link: https://ge.globo.com/ba/futebol/noticia/2023/03/08/com-aval-do-flamengo-bahia-avanca-em-conversas-com-marinho-para-fechar-contratacao.ghtml
# Link: https://ge.globo.com/futebol/times/palmeiras/noticia/2023/03/08/leila-confirma-interesse-em-allan-e-minimiza-pressao-por-reforcos-nao-contrato-por-nome.ghtml
# Link: https://ge.globo.com/negocios-do-esporte/noticia/2023/03/08/presidente-do-inter-defende-forte-futebol-e-explica-racha-com-libra-alguns-querem-garantir-receita-e-transferir-o-risco-para-outros.ghtml
# Link: https://ge.globo.com/futebol/times/fluminense/noticia/2023/03/08/marcelo-comenta-estreia-no-fluminense-em-2005-tudo-muito-rapido.ghtml
# Link: https://gq.globo.com/esporte-clube/noticia/2023/03/pia-sundhage-futebol-selecao-brasil.ghtml
# Link: https://gshow.globo.com/realities/bbb/bbb-23/bbb-ta-on/noticia/key-alves-revela-que-deixou-mensagem-para-gustavo-e-dispara-sobre-sexo-mentiroso.ghtml
# Link: https://gshow.globo.com/tudo-mais/tv-e-famosos/noticia/key-alves-se-declara-para-gustavo-nunca-tinha-vivido-algo-assim-estou-muito-apaixonada.ghtml
# Link: https://gshow.globo.com/realities/bbb/bbb-23/bbb-ta-on/noticia/key-alves-revela-que-ficou-com-gabriel-medina-e-brinca-de-beija-casa-ou-passa-com-famosos.ghtml
# Link: https://gshow.globo.com/realities/bbb/bbb-23/quarto-branco/noticia/domitila-barros-e-fred-discutem-no-quarto-branco.ghtml
# Link: https://gshow.globo.com/realities/bbb/bbb-23/dentro-da-casa/noticia/quarto-branco-do-bbb-23-domitila-fala-de-larissa-e-fred-reage.ghtml
# Link: https://gshow.globo.com/realities/bbb/bbb-23/quarto-branco/noticia/domitila-barros-e-fred-vao-para-o-quarto-branco-saiba-as-regras-do-duelo.ghtml
# Link: https://gshow.globo.com/realities/bbb/bbb-23/quarto-branco/noticia/domitila-barros-e-fred-sao-surpreendidos-por-carro-no-quarto-branco.ghtml
# Link: https://gshow.globo.com/realities/bbb/bbb-23/dentro-da-casa/noticia/no-bbb-23-fred-compara-domitila-a-juliette-e-sister-dispara-meu-nome-e-domitila-barros.ghtml
# Link: https://extra.globo.com/tv-e-lazer/bbb/botao-do-quarto-branco-liberado-no-bbb-23-domitila-abre-porta-nao-ve-vira-piada-25672069.html
# Link: https://g1.globo.com/politica/noticia/2023/03/08/8-de-marco-lula-anuncia-acoes-para-assegurar-direitos-das-mulheres-veja-lista.ghtml
# Link: https://ge.globo.com/olimpiadas/noticia/2023/03/08/ana-moser-anuncia-mudanca-no-bolsa-atleta-para-proteger-mulheres-na-gravidez.ghtml
# Link: https://g1.globo.com/politica/noticia/2023/03/08/janja-diz-ser-alvo-de-ataques-a-honra-e-critica-subrepresentacao-feminina-no-congresso.ghtml
# Link: https://g1.globo.com/podcast/o-assunto/noticia/2023/03/08/mulheres-na-politica-os-obstaculos-e-as-violencias-que-dificultam-a-representatividade-feminina-e-prejudicam-a-democracia.ghtml
# Link: https://oglobo.globo.com/politica/noticia/2023/03/jair-renan-bolsonaro-ganha-cargo-em-gabinete-do-senado.ghtml?utm_source=globo.com&utm_medium=oglobo
# Link: https://g1.globo.com/politica/noticia/2023/03/08/filho-04-de-bolsonaro-jair-renan-ganha-cargo-em-gabinete-de-senador-do-pl.ghtml
# Link: https://oglobo.globo.com/politica/noticia/2023/03/moraes-libera-149-mulheres-presas-em-atos-golpistas.ghtml?utm_source=globo.com&utm_medium=oglobo
# Link: https://g1.globo.com/politica/noticia/2023/03/08/moraes-determina-soltura-de-149-mulheres-detidas-nos-atos-golpistas-de-8-de-janeiro.ghtml
# Link: https://g1.globo.com/rs/rio-grande-do-sul/noticia/2023/03/08/toda-responsabilidade-diz-procurador-geral-do-trabalho-sobre-vinicolas-envolvidas-em-trabalho-semelhante-a-escravidao-no-rs.ghtml
# Link: https://g1.globo.com/rs/rio-grande-do-sul/noticia/2023/03/08/mpt-pede-bloqueio-de-bens-de-empresario-responsavel-por-trabalhadores-encontrados-em-situacao-de-escravidao-no-rs.ghtml
# Link: https://oglobo.globo.com/brasil/noticia/2023/03/caso-begolea-pericia-constatou-que-carne-na-casa-da-vitima-e-de-origem-animal.ghtml?utm_source=globo.com&utm_medium=oglobo
# Link: https://g1.globo.com/podcast/resumao-diario/noticia/2023/03/08/resumao-diario-500-bolsonaro-e-as-joias-e-uma-carta-para-messi.ghtml
# Link: https://gshow.globo.com/realities/bbb/
# Link: https://gshow.globo.com/realities/bbb/
# Link: https://gshow.globo.com/realities/bbb/
# Link: https://valor.globo.com/valor-data/?utm_source=globo.com&utm_medium=widget&utm_campaign=economia
# Link: https://valor.globo.com/valor-data/?utm_source=globo.com&utm_medium=widget&utm_campaign=economia
# Link: https://valor.globo.com/valor-data/?utm_source=globo.com&utm_medium=widget&utm_campaign=economia
# Link: https://ge.globo.com/agenda/?utm_source=globo.com&utm_medium=widget&utm_campaign=agenda#/pra-voce
# Link: https://ge.globo.com/agenda/?utm_source=globo.com&utm_medium=widget&utm_campaign=agenda
# Link: https://globoplay.globo.com/?origemId=2959&utm_source=gcom&utm_medium=home&utm_campaign=gcom-pirulito2&utm_term=logo
# Link: https://vitrine.globo.com/?origemId=2803&utm_source=gcom&utm_medium=home-franja-vitrine&utm_campaign=botao-assine
# Link: https://vitrine.globo.com/?origemId=2803&utm_source=gcom&utm_medium=home-franja-vitrine&utm_campaign=botao-assine
# Link: https://www.techtudo.com.br/noticias/2023/03/iphone-15-surgem-imagens-da-nova-geracao-da-apple-edmobile.ghtml
# Link: https://www.techtudo.com.br/listas/2023/03/fone-de-ouvido-tws-6-opcoes-bluetooth-a-partir-de-r-129-edqualcomprar.ghtml
# Link: https://www.techtudo.com.br/noticias/2023/03/veja-os-celulares-mais-vendidos-de-2022-iphone-domina-ranking-edmobile.ghtml
# Link: https://epocanegocios.globo.com/tecnologia/noticia/2023/03/os-milhares-de-trabalhadores-em-paises-pobres-que-abastecem-programas-de-inteligencia-artificial-como-o-chatgpt.ghtml
# Link: https://glamour.globo.com/lifestyle/capas/noticia/2023/03/zaika-dos-santos-e-capa-da-glamour-de-marco.ghtml
# Link: https://casavogue.globo.com/arquitetura/gente/noticia/2023/03/arinda-da-cruz-sobral-primeira-arquiteta-do-brasil.ghtml
# Link: https://receitas.globo.com/blog/curiosidades-e-gastronomia/influenciadoras-mulheres-que-vem-se-destacando-na-gastronomia.ghtml
# Link: https://autoesporte.globo.com/curiosidades/noticia/2023/03/como-e-a-vida-da-caminhoneira-que-dirige-10-mil-km-por-mes-nas-perigosas-estradas-do-artico.ghtml
# Link: https://revistagalileu.globo.com/sociedade/historia/noticia/2023/03/mary-wollstonecraft-quem-foi-a-mae-da-primeira-onda-do-feminismo.ghtml
# Link: https://vidadebicho.globo.com/comportamento/noticia/2023/03/cinco-marcas-pet-criadas-por-mulheres-com-historias-inspiradoras.ghtml
# Link: https://gshow.globo.com/novelas/travessia/noticia/travessia-guida-e-ari-vao-se-enfrentar-saiba-o-porque.ghtml
# Link: https://gshow.globo.com/novelas/vai-na-fe/vem-por-ai/noticia/em-vai-na-fe-lumiar-diz-para-sol-contar-a-verdade-sobre-jenifer-a-ben-e-ouve-ameaca.ghtml
# Link: https://gshow.globo.com/novelas/mar-do-sertao/vem-por-ai/noticia/firmino-pede-lorena-em-casamento-em-mar-do-sertao.ghtml
# Link: https://gshow.globo.com/podcast/papo-de-novela/noticia/dia-da-mulher-lilia-cabral-chora-ao-relembrar-personagem-que-inspirou-o-publico-feminino-saiba-quem.ghtml
# Link: https://globoplay.globo.com/v/11428910/?origemld=91139&utm_source=gcom&utm_medium=home&utm_campaign=gcom-edit&utm_term=clickbbb
# Link: https://globoplay.globo.com/v/11428796/?origemld=91139&utm_source=gcom&utm_medium=home&utm_campaign=gcom-edit&utm_term=integrabbb
# Link: https://vitrine.globo.com/assine/bbb?origemId=91139&utm_source=gcom&utm_medium=home-franja-video-gplay&utm_campaign=aq-org_gcom_vitrine_low_perf_banner_web_tier1_reality_bbb23&utm_content=banner&utm_term=card3-franjavideo-bbb23
# Link: https://g1.globo.com/economia/noticia/2023/03/07/dinheiro-esquecido-surpreende-jovem-entrei-achando-que-teria-10-centavos-mas-tinha-r-3-mil.ghtml
# Link: https://oglobo.globo.com/rio/noticia/2023/03/professor-suspeito-de-mandar-assassinar-gravida-em-campos-dos-goytacazes-e-preso.ghtml?utm_source=globo.com&utm_medium=oglobo
# Link: https://oglobo.globo.com/economia/noticia/2023/03/dinheiro-esquecido-uma-unica-pessoa-recebeu-r-328-mil-mais-r-60-milhoes-ja-foram-resgatados.ghtml?utm_source=globo.com&utm_medium=oglobo
# Link: https://g1.globo.com/sp/sao-paulo/noticia/2023/03/08/colisao-entre-trens-paralisa-trecho-da-linha-15-prata-do-metro-de-sp-na-manha-desta-quarta.ghtml
# Link: https://oglobo.globo.com/politica/noticia/2023/03/governo-incluiu-quatro-presentes-sauditas-em-acervo-no-dia-em-que-ex-ministro-voltou-de-viagem-joias-ficaram-de-fora.ghtml?utm_source=globo.com&utm_medium=oglobo
# Link: https://extra.globo.com/famosos/gabigol-compra-por-13-milhoes-mansao-no-rio-para-onde-se-mudou-ha-oito-meses-inicia-reforma-25671780.html
# Link: https://ge.globo.com/sp/santos-e-regiao/futebol/times/santos/noticia/2023/03/08/com-oferta-do-flamengo-angelo-faz-jogo-duro-para-sair-do-santos-e-mira-mercado-europeu.ghtml
# Link: https://ge.globo.com/rj/futebol/campeonato-carioca/noticia/2023/03/08/flamengo-x-fluminense-onde-assistir-ao-vivo-horario-e-escalacoes.ghtml
# Link: https://ge.globo.com/futebol/times/palmeiras/noticia/2023/03/08/palmeiras-fez-proposta-por-allan-tem-chance-de-sair-negocio-veja-como-esta-o-interesse-no-volante.ghtml
# Link: https://ge.globo.com/futebol/times/corinthians/noticia/2023/03/08/veja-sete-jogadores-que-ainda-nao-decolaram-no-corinthians-em-2023.ghtml
# Link: https://gshow.globo.com/realities/bbb/bbb-23/bate-papo-bbb/noticia/emocionada-key-alves-diz-que-pretende-casar-com-gustavo-vai-ser-no-rio-de-janeiro.ghtml
# Link: https://gshow.globo.com/realities/bbb/bbb-23/bate-papo-bbb/noticia/veja-reacao-de-key-alves-ao-ver-video-de-gustavo-olhando-larissa.ghtml
# Link: https://revistaquem.globo.com/noticias/noticia/2023/03/yasmin-brunet-mostra-marquinha-de-bronzeado-em-video-com-biquini-cavado.ghtml
# Link: https://gshow.globo.com/realities/bbb/bbb-23/eliminacao/noticia/sarah-aline-se-declara-para-ricardo-apos-escapar-do-paredao-do-bbb-23.ghtml
# Link: https://extra.globo.com/famosos/mansao-de-quatro-andares-herdada-por-viuva-de-pele-no-guaruja-tem-varanda-sobre-mar-estatua-do-jogador-elevador-fotos-25671882.html
# Link: https://g1.globo.com/
# Link: https://g1.globo.com/ac/acre/
# Link: https://g1.globo.com/al/alagoas/
# Link: https://g1.globo.com/ap/amapa/
# Link: https://g1.globo.com/am/amazonas/
# Link: https://g1.globo.com/ba/bahia/
# Link: https://g1.globo.com/bemestar/
# Link: https://g1.globo.com/bom-dia-brasil/
# Link: https://g1.globo.com/ce/ceara/
# Link: https://g1.globo.com/ciencia/
# Link: https://g1.globo.com/df/distrito-federal/
# Link: https://g1.globo.com/economia/
# Link: https://g1.globo.com/educacao/
# Link: https://g1.globo.com/empreendedorismo/
# Link: https://g1.globo.com/es/espirito-santo/
# Link: https://g1.globo.com/fantastico/
# Link: https://g1.globo.com/fato-ou-fake/
# Link: https://g1.globo.com/g1-em-1-minuto/playlist/videos-g1-em-1-minuto.ghtml
# Link: https://g1.globo.com/globonews/
# Link: https://g1.globo.com/globo-reporter/
# Link: https://g1.globo.com/go/goias/
# Link: https://g1.globo.com/hora1/
# Link: https://g1.globo.com/inovacao/
# Link: https://g1.globo.com/jornal-da-globo/
# Link: https://g1.globo.com/jornal-hoje/
# Link: https://g1.globo.com/jornal-nacional/
# Link: https://g1.globo.com/ma/maranhao/
# Link: https://g1.globo.com/mt/mato-grosso/
# Link: https://g1.globo.com/ms/mato-grosso-do-sul/
# Link: https://g1.globo.com/mg/minas-gerais/
# Link: https://g1.globo.com/meio-ambiente/
# Link: https://g1.globo.com/mundo/
# Link: https://g1.globo.com/olha-que-legal/
# Link: https://g1.globo.com/pa/para/
# Link: https://g1.globo.com/pb/paraiba/
# Link: https://g1.globo.com/pr/parana/
# Link: https://g1.globo.com/economia/pme/pequenas-empresas-grandes-negocios/
# Link: https://g1.globo.com/pe/pernambuco/
# Link: https://g1.globo.com/pi/piaui/
# Link: https://g1.globo.com/planeta-bizarro/
# Link: https://g1.globo.com/podcast/
# Link: https://g1.globo.com/politica/
# Link: https://g1.globo.com/pop-arte/
# Link: https://www.climatempo.com.br/
# Link: https://g1.globo.com/profissao-reporter/
# Link: https://g1.globo.com/rj/rio-de-janeiro/
# Link: https://g1.globo.com/rn/rio-grande-do-norte/
# Link: https://g1.globo.com/rs/rio-grande-do-sul/
# Link: https://g1.globo.com/ro/rondonia/
# Link: https://g1.globo.com/rr/roraima/
# Link: https://g1.globo.com/sc/santa-catarina/
# Link: https://g1.globo.com/saude/
# Link: https://g1.globo.com/sp/sao-paulo/
# Link: https://g1.globo.com/saude/
# Link: https://g1.globo.com/se/sergipe/
# Link: https://g1.globo.com/economia/tecnologia/
# Link: https://g1.globo.com/to/tocantins/
# Link: https://g1.globo.com/trabalho-e-carreira/
# Link: https://g1.globo.com/turismo-e-viagem/
# Link: https://g1.globo.com/especiais/guia-de-compras/
# Link: https://estuda.com/
# Link: https://ge.globo.com/
# Link: https://ge.globo.com/agenda/
# Link: http://globoesporte.globo.com/atletismo/
# Link: http://globoesporte.globo.com/basquete/
# Link: http://globoesporte.globo.com/futebol/brasileirao-serie-a/
# Link: http://globoesporte.globo.com/futebol/brasileirao-serie-b/
# Link: http://globoesporte.globo.com/rj/futebol/campeonato-carioca/index.html
# Link: http://globoesporte.globo.com/rs/futebol/campeonato-gaucho/index.html
# Link: http://globoesporte.globo.com/mg/futebol/campeonato-mineiro/index.html
# Link: http://globoesporte.globo.com/sp/futebol/campeonato-paulista/index.html
# Link: http://globoesporte.globo.com/cartola-fc/
# Link: http://globoesporte.globo.com/futebol/copa-do-mundo/index.html
# Link: https://ge.globo.com/futebol/copa-do-nordeste/
# Link: http://globoesporte.globo.com/futebol/copa-sul-americana/index.html
# Link: http://globoesporte.globo.com/programas/esporte-espetacular/
# Link: https://globoesporte.globo.com/esports/
# Link: https://globoesporte.globo.com/eu-atleta/
# Link: https://globoesporte.globo.com/motor/formula-1/
# Link: https://globoesporte.globo.com/futebol/
# Link: https://globoesporte.globo.com/futebol/futebol-internacional/
# Link: https://globoesporte.globo.com/futsal/
# Link: https://ge.globo.com/futebol/libertadores/
# Link: https://globoesporte.globo.com/futebol/futebol-internacional/liga-dos-campeoes/
# Link: https://ge.globo.com/basquete/nba/
# Link: http://globoesporte.globo.com/basquete/nbb/
# Link: https://globoesporte.globo.com/olimpiadas/
# Link: https://globoesporte.globo.com/futebol/selecao-brasileira/
# Link: https://ge.globo.com/skate/
# Link: https://globoesporte.globo.com/radicais/surfe/
# Link: https://globoesporte.globo.com/tenis/
# Link: https://globoesporte.globo.com/volei/
# Link: http://gshow.globo.com/
# Link: https://gshow.globo.com/realities/bbb/
# Link: https://gshow.globo.com/novelas/travessia/
# Link: https://gshow.globo.com/novelas/cara-e-coragem/
# Link: https://gshow.globo.com/novelas/mar-do-sertao/
# Link: https://gshow.globo.com/novelas/todas-as-flores/
# Link: https://gshow.globo.com/tudo-mais/
# Link: https://gshow.globo.com/tudo-mais/tv-e-famosos/
# Link: https://gshow.globo.com/tudo-mais/pop/
# Link: https://gshow.globo.com/tudo-mais/viralizou/
# Link: https://gshow.globo.com/horoscopo-etc/
# Link: https://gshow.globo.com/moda-e-beleza/
# Link: https://gshow.globo.com/realities/no-limite/2022/
# Link: https://gshow.globo.com/realities/the-masked-singer-brasil/
# Link: https://gshow.globo.com/realities/the-voice-brasil/
# Link: https://gshow.globo.com/realities/the-voice-kids/2022/
# Link: https://gshow.globo.com/gnt/
# Link: https://gshow.globo.com/podcast/
# Link: https://receitas.globo.com/
# Link: https://receitas.globo.com/tipos-de-prato/doces-e-sobremesas/
# Link: https://receitas.globo.com/tipos-de-prato/tortas-e-bolos/
# Link: https://receitas.globo.com/tipos-de-prato/massas/
# Link: https://receitas.globo.com/tipos-de-prato/saladas/
# Link: https://receitas.globo.com/tipos-de-prato/carnes/
# Link: https://receitas.globo.com/tipos-de-prato/aves/
# Link: https://receitas.globo.com/tipos-de-prato/peixes-e-frutos-do-mar/
# Link: https://receitas.globo.com/ocasioes/cafe-da-manha/
# Link: https://receitas.globo.com/ocasioes/almoco/
# Link: https://receitas.globo.com/ocasioes/lanche-da-tarde/
# Link: https://receitas.globo.com/ocasioes/jantar/
# Link: https://receitas.globo.com/ocasioes/pascoa/
# Link: https://receitas.globo.com/ocasioes/natal/
# Link: https://receitas.globo.com/ocasioes/ano-novo/
# Link: https://receitas.globo.com/programas-e-series/mais-voce/
# Link: https://receitas.globo.com/programas-e-series/e-de-casa/
# Link: https://receitas.globo.com/programas-e-series/mestre-do-sabor/
# Link: https://receitas.globo.com/programas-e-series/cozinha-pratica/
# Link: https://receitas.globo.com/programas-e-series/tempero-de-familia/
# Link: https://receitas.globo.com/programas-e-series/bela-cozinha/
# Link: https://receitas.globo.com/programas-e-series/perto-do-fogo/
# Link: https://receitas.globo.com/programas-e-series/que-marravilha/
# Link: https://receitas.globo.com/programas-e-series/rainha-da-cocada/
# Link: https://receitas.globo.com/programas-e-series/se-joga/
# Link: https://receitas.globo.com/programas-e-series/bbb/
# Link: https://receitas.globo.com/programas-e-series/receitas-do-joaquim/
# Link: https://receitas.globo.com/programas-e-series/receitas-dos-famosos/
# Link: https://receitas.globo.com/programas-e-series/dulce-delight/
# Link: https://receitas.globo.com/programas-e-series/mais-voce/
# Link: https://receitas.globo.com/programas-e-series/cozinha-pratica/
# Link: https://receitas.globo.com/programas-e-series/tempero-de-familia/
# Link: https://globoplay.globo.com/
# Link: https://globoplay.globo.com/tv-globo/ao-vivo/6120663/
# Link: https://globoplay.globo.com/categorias/big-brother-brasil/
# Link: https://globoplay.globo.com/categorias/novelas/
# Link: https://globoplay.globo.com/categorias/series/
# Link: https://globoplay.globo.com/cinema/
# Link: https://globoplay.globo.com/canais/
# Link: https://globoplay.globo.com/categorias/novidades/
# Link: https://globoplay.globo.com/categorias/top-10/
# Link: https://globoplay.globo.com/categorias/esportes/
# Link: https://globoplay.globo.com/categorias/originais-globoplay/
# Link: https://globoplay.globo.com/categorias/dia-da-mulher/
# Link: https://globoplay.globo.com/categorias/series-filmes-documentarios-lgbt/
# Link: https://globoplay.globo.com/categorias/consciencia-negra/
# Link: https://globoplay.globo.com/canais/franquias-e-spin-offs/
# Link: https://globoplay.globo.com/canais/sagas/
# Link: https://globoplay.globo.com/podcasts/
# Link: https://globoplay.globo.com/categorias/jornalismo/
# Link: https://globoplay.globo.com/categorias/infantil/
# Link: https://globoplay.globo.com/categorias/variedades/
# Link: https://globoplay.globo.com/categorias/reality-shows/
# Link: https://globoplay.globo.com/categorias/documentarios/
# Link: https://globoplay.globo.com/categorias/especiais/
# Link: https://globoplay.globo.com/categorias/humor/
# Link: https://globoplay.globo.com/canais/telecine/
# Link: https://globoplay.globo.com/canais/lionsgateplus/
# Link: http://grupoglobo.globo.com/
# Link: http://g1.globo.com/principios-editoriais-do-grupo-globo.html
# Link: https://historia.globo.com/
# Link: https://memoriaglobo.globo.com/
# Link: http://somos.globo.com
# Link: https://redeglobo.globo.com/
# Link: http://globofilmes.globo.com/
# Link: https://www.publicidadeeditoraglobo.com.br/
# Link: http://revistaautoesporte.globo.com/
# Link: http://revistacasaejardim.globo.com/
# Link: http://casavogue.globo.com/
# Link: http://revistacrescer.globo.com/
# Link: http://revistaepoca.globo.com/
# Link: http://epocanegocios.globo.com/
# Link: http://extra.globo.com/
# Link: http://revistagalileu.globo.com/
# Link: http://revistaglamour.globo.com/
# Link: http://revistagloborural.globo.com/
# Link: http://gq.globo.com/
# Link: http://revistamarieclaire.globo.com/
# Link: http://revistamonet.globo.com/
# Link: http://oglobo.globo.com/
# Link: http://revistapegn.globo.com/
# Link: http://revistaquem.globo.com/
# Link: https://umsoplaneta.globo.com/
# Link: http://www.valor.com.br/
# Link: https://valorinveste.globo.com/
# Link: http://vogue.globo.com/
# Link: https://www.techtudo.com.br/
# Link: https://www.techtudo.com.br/mobile/
# Link: https://www.techtudo.com.br/eletronicos/tvs/
# Link: https://www.techtudo.com.br/informatica/notebooks/
# Link: https://www.techtudo.com.br/jogos/
# Link: https://www.techtudo.com.br/e-sports/
# Link: https://www.techtudo.com.br/softwares/apps/
# Link: https://www.techtudo.com.br/softwares/apps/redes-sociais/
# Link: https://www.techtudo.com.br/dicas-e-tutoriais/plantao.html
# Link: https://www.techtudo.com.br/reviews/plantao.html
# Link: https://www.techtudo.com.br/listas/plantao.html
# Link: https://www.techtudo.com.br/videos/
# Link: https://forum.techtudo.globo.com/
# Link: https://canaisglobo.globo.com/
# Link: https://globoplay.globo.com/canais/bis/
# Link: https://globoplay.globo.com/canais/canal-brasil/
# Link: https://canaloff.globo.com/
# Link: http://combate.globo.com/
# Link: https://globoplay.globo.com/canais/futura/
# Link: https://globoplay.globo.com/canais/globonews/
# Link: http://mundogloob.globo.com/
# Link: https://globoplay.globo.com/canais/gloobinho/
# Link: http://gnt.globo.com/
# Link: https://globoplay.globo.com/canais/modo-viagem/
# Link: https://globoplay.globo.com/canais/megapix/
# Link: http://multishow.globo.com/
# Link: https://globoesporte.globo.com/loja/premiere/?origemId=954
# Link: https://globoesporte.globo.com/sportv/
# Link: https://www.telecineplay.com.br/
# Link: https://globoplay.globo.com/canais/universal/
# Link: https://globoplay.globo.com/canais/viva/
# Link: http://radioglobo.globo.com/
# Link: https://bhfm.globo.com/
# Link: https://cbn.globoradio.globo.com/
# Link: https://radioglobo.globo.com/
# Link: https://vempraglobo.g.globo/
# Link: https://conta.globo.com/
# Link: https://globoventures.globo.com/
# Link: https://www.alice.com.br/
# Link: https://arena.im/
# Link: https://www.buser.com.br
# Link: https://www.emcasa.com
# Link: https://www.enjoei.com.br
# Link: https://site.franq.com.br/
# Link: https://www.gabriel.com.br
# Link: https://galena.com/
# Link: https://www.hashdex.com.br
# Link: https://www.idwall.co
# Link: https://www.ingresse.com
# Link: https://www.kovi.com.br
# Link: https://www.livup.com.br/
# Link: https://www.lojadomecanico.com.br
# Link: https://www.merama.io/
# Link: https://www.nomadglobal.com
# Link: https://olist.com/
# Link: https://www.orama.com.br
# Link: https://www.p1gg.com.br
# Link: https://petlove.com.br
# Link: https://www.polen.me
# Link: https://prozeducacao.com.br/
# Link: https://www.quintoandar.com.br/
# Link: https://www.sooper.com.br
# Link: https://www.stone.com.br
# Link: https://www.winnin.com
# Link: https://zippi.com.br/
# Link: https://www.globo.com/
# Link: https://www.globo.com/todos-os-sites/
# Link: http://g1.globo.com/principios-editoriais-do-grupo-globo.html
# Link: https://privacidade.globo.com/privacy-policy/
# Link: https://minhaconta.globo.com/
# Link: http://negocios8.redeglobo.com.br/Paginas/Midia-Kit.aspx
# URL: http://www.cnpq.brURL: https://www.uai.com.br
#
# Link: #wrapper
# Link: /
# Link: #main-navigation
# Link: #govbr-busca-input
# Link: #portal-footer
# Link: https://www.gov.br/pt-br
# Link: https://www.gov.br/mcti
# Link: #
# Link: https://www.gov.br/pt-br/orgaos-do-governo
# Link: https://www.gov.br/acessoainformacao/pt-br
# Link: http://www4.planalto.gov.br/legislacao
# Link: https://www.gov.br/governodigital/pt-br/acessibilidade-digital
# Link: #
# Link: #
# Link: #
# Link: https://www.gov.br/cnpq/pt-br
# Link: https://www.gov.br/cnpq/pt-br/assuntos
# Link: https://www.gov.br/cnpq/pt-br/assuntos/noticias
# Link: https://www.gov.br/cnpq/pt-br/assuntos/noticias/pesquisa-do-dia
# Link: https://www.gov.br/cnpq/pt-br/assuntos/noticias/destaque-em-cti
# Link: https://www.gov.br/cnpq/pt-br/assuntos/noticias/cnpq-em-acao
# Link: https://www.gov.br/cnpq/pt-br/assuntos/noticias/premios
# Link: https://www.gov.br/cnpq/pt-br/assuntos/noticias/atualidades
# Link: https://www.gov.br/cnpq/pt-br/assuntos/noticias/oportunidades-externas
# Link: https://www.gov.br/cnpq/pt-br/assuntos/popularizacao-da-ciencia
# Link: https://www.gov.br/cnpq/pt-br/assuntos/popularizacao-da-ciencia/por-que-popularizar
# Link: https://www.gov.br/cnpq/pt-br/assuntos/popularizacao-da-ciencia/o-cnpq-e-a-divulgacao-cientifica
# Link: https://www.gov.br/cnpq/pt-br/assuntos/popularizacao-da-ciencia/semana-nacional-de-ciencia-e-tecnologia
# Link: https://www.gov.br/cnpq/pt-br/assuntos/popularizacao-da-ciencia/museus-e-centros-de-ciencia
# Link: https://www.gov.br/cnpq/pt-br/assuntos/popularizacao-da-ciencia/feiras-e-mostras-de-ciencias
# Link: https://www.gov.br/cnpq/pt-br/assuntos/popularizacao-da-ciencia/programa-editorial
# Link: https://www.gov.br/cnpq/pt-br/assuntos/popularizacao-da-ciencia/olimpiadas-cientificas
# Link: https://www.gov.br/cnpq/pt-br/acesso-a-informacao/acoes-e-programas/programas/mulher-e-ciencia/pioneiras-da-ciencia-1?_authenticator=a51028b6835961b665c9d2d2c308df3edc24c4b0
# Link: https://www.gov.br/cnpq/pt-br/assuntos/popularizacao-da-ciencia/premios
# Link: https://www.gov.br/cnpq/pt-br/assuntos/popularizacao-da-ciencia/entrevistas
# Link: https://www.gov.br/cnpq/pt-br/assuntos/popularizacao-da-ciencia/relatorios-de-pesquisa
# Link: https://www.gov.br/cnpq/pt-br/assuntos/popularizacao-da-ciencia/links-interessantes
# Link: https://www.gov.br/cnpq/pt-br/assuntos/centro-de-memoria
# Link: http://centrodememoria.cnpq.br/cmemoria-index.html
# Link: https://www.gov.br/cnpq/pt-br/acesso-a-informacao
# Link: https://www.gov.br/cnpq/pt-br/acesso-a-informacao/institucional
# Link: https://www.gov.br/cnpq/pt-br/acesso-a-informacao/institucional/institucional
# Link: https://www.gov.br/cnpq/pt-br/acesso-a-informacao/institucional/historico
# Link: https://www.gov.br/cnpq/pt-br/acesso-a-informacao/institucional/biografia-do-presidente
# Link: https://www.gov.br/cnpq/pt-br/acesso-a-informacao/institucional/copy_of_organograma
# Link: https://www.gov.br/cnpq/pt-br/acesso-a-informacao/institucional/copy2_of_quem-e-quem
# Link: https://www.gov.br/cnpq/pt-br/acesso-a-informacao/institucional/competencias
# Link: https://www.gov.br/cnpq/pt-br/acesso-a-informacao/institucional/base-juridica
# Link: https://www.gov.br/cnpq/pt-br/acesso-a-informacao/institucional/corregedoria
# Link: https://www.gov.br/cnpq/pt-br/acesso-a-informacao/agenda-de-autoridades
# Link: https://www.gov.br/cnpq/pt-br/acesso-a-informacao/acoes-e-programas
# Link: https://www.gov.br/cnpq/pt-br/acesso-a-informacao/acoes-e-programas/programas
# Link: https://www.gov.br/cnpq/pt-br/acesso-a-informacao/acoes-e-programas/parcerias
# Link: https://www.gov.br/cnpq/pt-br/acesso-a-informacao/acoes-e-programas/servicos
# Link: https://www.gov.br/cnpq/pt-br/acesso-a-informacao/acoes-e-programas/premios
# Link: https://www.gov.br/cnpq/pt-br/acesso-a-informacao/bolsas-e-auxilios
# Link: https://www.gov.br/cnpq/pt-br/acesso-a-informacao/bolsas-e-auxilios/apresentacao
# Link: https://www.gov.br/cnpq/pt-br/acesso-a-informacao/bolsas-e-auxilios/copy_of_modalidades
# Link: https://www.gov.br/cnpq/pt-br/acesso-a-informacao/bolsas-e-auxilios/auxilios-1
# Link: https://www.gov.br/cnpq/pt-br/acesso-a-informacao/bolsas-e-auxilios/auxilios-cartao-pesquisa
# Link: https://www.gov.br/cnpq/pt-br/acesso-a-informacao/bolsas-e-auxilios/bolsas-cartao-bolsista-exterior
# Link: http://memoria2.cnpq.br/web/guest/chamadas-publicas?p_p_id=resultadosportlet_WAR_resultadoscnpqportlet_INSTANCE_0ZaM&filtro=abertas/
# Link: http://memoria2.cnpq.br/web/guest/chamadas-publicas?p_p_id=resultadosportlet_WAR_resultadoscnpqportlet_INSTANCE_0ZaM&filtro=encerradas/
# Link: http://memoria2.cnpq.br/web/guest/chamadas-publicas?p_p_id=resultadosportlet_WAR_resultadoscnpqportlet_INSTANCE_0ZaM&filtro=resultados/
# Link: http://memoria2.cnpq.br/bolsistas-vigentes
# Link: https://www.gov.br/cnpq/pt-br/acesso-a-informacao/bolsas-e-auxilios/bolsistas-egressos
# Link: https://www.gov.br/cnpq/pt-br/acesso-a-informacao/bolsas-e-auxilios/prestacao-de-contas
# Link: https://www.gov.br/cnpq/pt-br/acesso-a-informacao/normas-1
# Link: https://www.gov.br/cnpq/pt-br/acesso-a-informacao/normas-1/lei-no-1-310-de-15-de-janeiro-de-1951
# Link: https://www.gov.br/cnpq/pt-br/acesso-a-informacao/normas-1/regimento-interno-1
# Link: https://www.gov.br/cnpq/pt-br/acesso-a-informacao/normas-1/estatuto-do-cnpq
# Link: http://memoria2.cnpq.br/web/guest/normas?p_p_id=normascnpqportlet_WAR_normascnpqportlet_INSTANCE_yUx3jBhkd0TD&p_p_lifecycle=0&p_p_state=normal&p_p_mode=view&p_p_col_id=column-2&p_p_col_pos=1&p_p_col_count=2&nomeCategoriaPai=inst_servicos&codigoCategoriaPai=219452&nomeCategoria=inst_servicos&codigoCategoria=219452&modo=pai
# Link: https://www.gov.br/cnpq/pt-br/acesso-a-informacao/participacao-social
# Link: https://www.gov.br/cnpq/pt-br/acesso-a-informacao/planejamento-e-governanca
# Link: https://www.gov.br/cnpq/pt-br/acesso-a-informacao/planejamento-e-governanca/planejamento
# Link: https://www.gov.br/cnpq/pt-br/acesso-a-informacao/planejamento-e-governanca/ppa-2020-2023-2
# Link: https://www.gov.br/cnpq/pt-br/acesso-a-informacao/planejamento-e-governanca/orcamento-1
# Link: https://www.gov.br/cnpq/pt-br/acesso-a-informacao/planejamento-e-governanca/governanca
# Link: https://www.gov.br/cnpq/pt-br/acesso-a-informacao/auditorias
# Link: https://www.gov.br/cnpq/pt-br/acesso-a-informacao/auditorias/prestacao-de-contas
# Link: https://www.gov.br/cnpq/pt-br/acesso-a-informacao/auditorias/auditoria-interna
# Link: https://www.gov.br/cnpq/pt-br/acesso-a-informacao/convenios-e-transferencias
# Link: https://www.gov.br/cnpq/pt-br/acesso-a-informacao/convenios-e-transferencias/convenios
# Link: https://www.gov.br/cnpq/pt-br/acesso-a-informacao/convenios-e-transferencias/ted
# Link: https://www.gov.br/cnpq/pt-br/acesso-a-informacao/convenios-e-transferencias/emendas-parlamentares
# Link: https://www.gov.br/cnpq/pt-br/acesso-a-informacao/receitas-e-despesas
# Link: https://www.gov.br/cnpq/pt-br/acesso-a-informacao/receitas-e-despesas/despesas
# Link: https://www.gov.br/cnpq/pt-br/acesso-a-informacao/licitacoes-e-contratos
# Link: http://memoria2.cnpq.br/web/guest/licitacoes/
# Link: http://memoria2.cnpq.br/web/guest/contratos/
# Link: https://www.gov.br/cnpq/pt-br/acesso-a-informacao/servidores
# Link: https://www.gov.br/cnpq/pt-br/acesso-a-informacao/servidores/servidores-cnpq
# Link: https://www.gov.br/cnpq/pt-br/acesso-a-informacao/servidores/desenvolvimento-pessoal
# Link: https://www.gov.br/cnpq/pt-br/acesso-a-informacao/servidores/terceirizacao
# Link: https://www.gov.br/cnpq/pt-br/acesso-a-informacao/informacoes-classificadas-1
# Link: https://www.gov.br/cnpq/pt-br/acesso-a-informacao/servico-de-informacao-ao-cidadao
# Link: https://www.gov.br/cnpq/pt-br/acesso-a-informacao/servico-de-informacao-ao-cidadao/apresentacao
# Link: https://www.gov.br/cnpq/pt-br/acesso-a-informacao/servico-de-informacao-ao-cidadao/e-sic
# Link: https://www.gov.br/cnpq/pt-br/acesso-a-informacao/servico-de-informacao-ao-cidadao/lei
# Link: https://www.gov.br/cnpq/pt-br/acesso-a-informacao/servico-de-informacao-ao-cidadao/ouvidoria
# Link: https://www.gov.br/cnpq/pt-br/acesso-a-informacao/servico-de-informacao-ao-cidadao/ouvidoria-publicacoes
# Link: https://www.gov.br/cnpq/pt-br/acesso-a-informacao/dados-abertos
# Link: https://www.gov.br/cnpq/pt-br/acesso-a-informacao/dados-abertos/consulta-de-dados
# Link: http://dadosabertos.cnpq.br/pt_BR/
# Link: https://www.gov.br/cnpq/pt-br/acesso-a-informacao/pdtic
# Link: https://www.gov.br/cnpq/pt-br/acesso-a-informacao/perguntas-frequentes
# Link: https://www.gov.br/cnpq/pt-br/composicao
# Link: https://www.gov.br/cnpq/pt-br/composicao/conselho-deliberativo
# Link: https://www.gov.br/cnpq/pt-br/composicao/diretoria-executiva-1
# Link: https://www.gov.br/cnpq/pt-br/composicao/diretoria-executiva-1/presidencia
# Link: https://www.gov.br/cnpq/pt-br/composicao/diretoria-executiva-1/copy_of_diretoria-de-engenharias-ciencias-exatas-humanas-e-sociais-dehs
# Link: https://www.gov.br/cnpq/pt-br/composicao/diretoria-executiva-1/copy_of_diretoria-de-gestao-e-tecnologia-da-informacao-dgti
# Link: https://www.gov.br/cnpq/pt-br/composicao/diretoria-executiva-1/copy_of_diretoria-de-cooperacao-institucional
# Link: https://www.gov.br/cnpq/pt-br/composicao/diretoria-executiva-1/copy_of_diretoria-de-ciencias-agrarias-biologicas-e-da-saude-dabs
# Link: https://www.gov.br/cnpq/pt-br/composicao/comites-de-assessoramento
# Link: https://www.gov.br/cnpq/pt-br/composicao/comites-de-assessoramento/apresentacao
# Link: https://www.gov.br/cnpq/pt-br/composicao/comites-de-assessoramento/membros
# Link: https://www.gov.br/cnpq/pt-br/composicao/comites-de-assessoramento/criterios-de-julgamento
# Link: https://www.gov.br/cnpq/pt-br/composicao/comites-de-assessoramento/calendario
# Link: https://www.gov.br/cnpq/pt-br/composicao/comites-de-assessoramento/normas
# Link: https://www.gov.br/cnpq/pt-br/composicao/comites-de-assessoramento/renovacao-de-cas
# Link: https://www.gov.br/cnpq/pt-br/composicao/comissao-de-integridade
# Link: https://www.gov.br/cnpq/pt-br/composicao/comissao-de-integridade/apresentacao
# Link: https://www.gov.br/cnpq/pt-br/composicao/comissao-de-integridade/composicao
# Link: https://www.gov.br/cnpq/pt-br/composicao/comissao-de-integridade/diretrizes
# Link: https://www.gov.br/cnpq/pt-br/composicao/comissao-de-integridade/documentos
# Link: https://www.gov.br/cnpq/pt-br/composicao/comissao-de-etica
# Link: https://www.gov.br/cnpq/pt-br/composicao/comissao-de-etica/apresentacao
# Link: https://www.gov.br/cnpq/pt-br/composicao/comissao-de-etica/legislacao
# Link: https://www.gov.br/cnpq/pt-br/centrais-de-conteudo
# Link: https://www.gov.br/cnpq/pt-br/centrais-de-conteudo/publicacoes
# Link: https://www.gov.br/cnpq/pt-br/centrais-de-conteudo/publicacoes/impressos
# Link: https://www.gov.br/cnpq/pt-br/centrais-de-conteudo/publicacoes/divulgacao-cientifica
# Link: https://www.gov.br/cnpq/pt-br/centrais-de-conteudo/publicacoes/palestras
# Link: https://soundcloud.com/user-349483946
# Link: https://www.flickr.com/photos/cnpqoficial
# Link: https://www.youtube.com/cnpqoficial
# Link: https://www.gov.br/cnpq/pt-br/canais_atendimento
# Link: https://www.gov.br/cnpq/pt-br/canais_atendimento/fale-conosco
# Link: https://www.gov.br/cnpq/pt-br/canais_atendimento/imprensa
# Link: https://www.gov.br/cnpq/pt-br/canais_atendimento/imprensa/contato
# Link: https://www.gov.br/cnpq/pt-br/canais_atendimento/identidade-visual
# Link: https://www.gov.br/cnpq/pt-br/canais_atendimento/identidade-visual/identidade-visual
# Link: https://www.gov.br/cnpq/pt-br/canais_atendimento/identidade-visual/manual-de-aplicacao
# Link: https://sisgen-pesquisa.cnpq.br
# Link: https://www.gov.br/cnpq/pt-br/revistaq
# Link: https://www.gov.br/cnpq/pt-br/pagina-inicial
# Link: https://www.gov.br/pt-br/servicos
# Link: https://www.gov.br/pt-br/servicos/buscar-servicos-por
# Link: https://www.gov.br/pt-br/categorias
# Link: https://www.gov.br/pt-br/servicos/listar_orgaos
# Link: https://www.gov.br/pt-br/servicos-estaduais
# Link: https://www.gov.br/pt-br/servicos/servicos-por-publico-alvo
# Link: https://www.gov.br/pt-br/servicos/listar_servicos_segmento?segmento=publico_alvo_cidadaos
# Link: https://www.gov.br/pt-br/servicos/listar_servicos_segmento?segmento=publico_alvo_empresas
# Link: https://www.gov.br/pt-br/servicos/listar_servicos_segmento?segmento=publico_alvo_orgaos
# Link: https://www.gov.br/pt-br/servicos/listar_servicos_segmento?segmento=publico_alvo_outros
# Link: https://www.gov.br/pt-br/servicos/listar_servicos_segmento?segmento=publico_alvo_servidor
# Link: https://www.gov.br/pt-br/noticias
# Link: https://www.gov.br/pt-br/noticias/servicos-para-o-cidadao
# Link: https://www.gov.br/pt-br/noticias/saude-e-vigilancia-sanitaria
# Link: https://www.gov.br/pt-br/noticias/agricultura-e-pecuaria
# Link: https://www.gov.br/pt-br/noticias/assistencia-social
# Link: https://www.gov.br/pt-br/noticias/ciencia-e-tecnologia
# Link: https://www.gov.br/pt-br/noticias/comunicacao
# Link: https://www.gov.br/pt-br/noticias/cultura-artes-historia-e-esportes
# Link: https://www.gov.br/pt-br/noticias/financas-impostos-e-gestao-publica
# Link: https://www.gov.br/pt-br/noticias/educacao-e-pesquisa
# Link: https://www.gov.br/pt-br/noticias/energia-minerais-e-combustiveis
# Link: https://www.gov.br/pt-br/noticias/forcas-armadas
# Link: https://www.gov.br/pt-br/noticias/transito-e-transportes
# Link: https://www.gov.br/pt-br/noticias/justica-e-seguranca
# Link: https://www.gov.br/pt-br/noticias/meio-ambiente-e-clima
# Link: https://www.gov.br/pt-br/noticias/trabalho-e-previdencia
# Link: https://www.gov.br/pt-br/noticias/viagens-e-turismo
# Link: https://www.gov.br/pt-br/apps/@@galeria-de-aplicativos
# Link: /planalto
# Link: https://www.gov.br/pt-br/navegacao
# Link: https://www.gov.br/governodigital/pt-br/acessibilidade-digital
# Link: https://www.gov.br/pt-br/sitemap
# Link: /pt-br/termos-de-uso
# Link: https://gov.br/sobre
# Link: http://solicitacao.servicos.gov.br/
# Link: https://www.gov.br/pt-br/orgaos-do-governo
# Link: https://www.gov.br/pt-br/temas-em-destaque-1
# Link: https://www.gov.br/pt-br/por-dentro-do-govbr
# Link: https://www.gov.br/pt-br/por-dentro-do-govbr/perguntas-frequentes
# Link: http://faq-login-unico.servicos.gov.br/en/latest/
# Link: https://www.gov.br/pt-br/por-dentro-do-govbr/ajuda-para-navegar-o-portal
# Link: https://www.gov.br/pt-br/por-dentro-do-govbr/conheca-os-elementos-do-portal
# Link: https://www.gov.br/participamaisbrasil/sobre
# Link: /pt-br/termos-de-uso
# Link: https://www.gov.br/governodigital/pt-br
# Link: https://www.gov.br/pt-br/guia-de-edicao-de-servicos-do-gov.br/bem-vindo-editor
# Link: https://www.gov.br/pt-br/dados-do-governo-federal
# Link: /governodigital/pt-br/dados-abertos
# Link: /economia/pt-br/acesso-a-informacao/servidores/servidores-publicos/painel-estatistico-de-pessoal
# Link: http://paineldecompras.economia.gov.br
# Link: /acessoainformacao/pt-br
# Link: https://www.gov.br/pt-br/apps/@@galeria-de-aplicativos
# Link: https://www.gov.br/pt-br/participacao-social
# Link: https://www.gov.br/pt-br/apps/@@galeria-de-aplicativos
# Link: https://www.gov.br/pt-br/participacao-social
# Link: https://www.twitter.com/CNPq_Oficial
# Link: https://www.youtube.com/CNPqOficial
# Link: https://www.facebook.com/cnpqoficial
# Link: https://www.instagram.com/cnpq_oficial
# Link: https://www.flickr.com/cnpqoficial
# Link: #
# Link: #
# Link: #
# Link: #
# Link: #
# Link: #
# Link: #
# Link: #
# Link: https://www.gov.br/pt-br/servicos/consultar-cadastro-de-pessoas-fisicas
# Link: https://www.gov.br/pt-br/servicos/receber-o-abono-salarial
# Link: https://www.gov.br/pt-br/servicos/consultar-e-solicitar-a-devolucao-de-valores-a-receber
# Link: https://www.gov.br/pt-br/servicos/obter-a-carteira-de-trabalho
# Link: https://www.gov.br/pt-br/servicos/consultar-restituicao-de-imposto-de-renda
# Link: https://www.gov.br/pt-br/servicos/emitir-certidao-de-regularidade-fiscal
# Link: https://www.gov.br/pt-br/servicos/solicitar-bolsa-podio
# Link: https://www.gov.br/pt-br/servicos/inscrever-se-no-sisu-sistema-de-selecao-unificada
# Link: https://www.gov.br/pt-br/servicos/obter-bolsa-de-estudo-do-prouni
# ...
# Link: https://epocanegocios.globo.com/especiais/web-summit/noticia/2022/12/download-web-summit-e-book-reune-principais-insights-da-conferencia-de-2022-e-aponta-as-tendencias-para-2023.ghtml
# Link: https://epocanegocios.globo.com/especiais/web-summit/noticia/2022/12/download-web-summit-e-book-reune-principais-insights-da-conferencia-de-2022-e-aponta-as-tendencias-para-2023.ghtml
# Link: https://epocanegocios.globo.com/360/fotos/2022/10/empresas-vencedoras-do-premio-epoca-negocios-360-em-2022.html
# Link: https://epocanegocios.globo.com/360/fotos/2022/10/empresas-vencedoras-do-premio-epoca-negocios-360-em-2022.html
# Link: https://epocanegocios.globo.com/360/fotos/2022/10/veja-como-foi-festa-de-entrega-do-anuario-epoca-negocios-360-2022.html
# Link: https://epocanegocios.globo.com/360/fotos/2022/10/veja-como-foi-festa-de-entrega-do-anuario-epoca-negocios-360-2022.html
# Link: https://epocanegocios.globo.com/360/noticia/2022/10/epoca-negocios-360-conheca-30-melhores-empresas-do-brasil-em-2022.html
# Link: https://epocanegocios.globo.com/especiais/melhores-empresas-para-trabalhar/noticia/2022/10/gptw-conheca-as-melhores-empresas-para-trabalhar-no-brasil-2022.ghtml
# Link: https://epocanegocios.globo.com/especiais/melhores-empresas-para-trabalhar/noticia/2022/10/gptw-conheca-as-melhores-empresas-para-trabalhar-no-brasil-2022.ghtml
# Link: https://epocanegocios.globo.com/carreira/noticia/2022/10/gptw-veja-como-foi-a-premiacao-das-melhores-empresas-para-trabalhar-em-2022.ghtml
# Link: https://epocanegocios.globo.com/carreira/noticia/2022/10/gptw-veja-como-foi-a-premiacao-das-melhores-empresas-para-trabalhar-em-2022.ghtml
# Link: https://epocanegocios.globo.com/principios-editoriais-do-grupo-globo/
# Link: https://privacidade.globo.com/privacy-policy/
# Link: https://epocanegocios.globo.com/termos-de-uso/
# URL: https://forum.techtudo.globo.com/
# Link: https://www.techtudo.com.br/ultimas/
# Link: https://www.techtudo.com.br/noticias/
# Link: https://www.techtudo.com.br/dicas-e-tutoriais/
# Link: https://www.techtudo.com.br/listas/
# Link: https://www.techtudo.com.br/reviews/
# Link: https://www.techtudo.com.br/playlist/videos-techtudo/
# Link: https://www.techtudo.com.br/tudo-sobre/
# Link: https://www.techtudo.com.br/mobile/
# Link: https://www.techtudo.com.br/mobile/
# Link: https://www.techtudo.com.br/mobile/tablets/
# Link: https://www.techtudo.com.br/mobile/telefonia/
# Link: https://www.techtudo.com.br/mobile/smartwatches/
# Link: https://www.techtudo.com.br/mobile/e-reader/
# Link: https://www.techtudo.com.br/mobile/android/index.html
# Link: https://www.techtudo.com.br/mobile/ios/index.html
# Link: https://forum.techtudo.com.br/tags/celular/?utm_source=techtudo.com&utm_medium=referral&utm_campaign=site
# Link:
# Link: https://www.techtudo.com.br/tudo-sobre/iphone-14/
# Link: https://www.techtudo.com.br/tudo-sobre/iphone-13/
# Link: https://www.techtudo.com.br/tudo-sobre/galaxy-s22-ultra/
# Link: https://www.techtudo.com.br/tudo-sobre/moto-g-stylus/
# Link: https://www.techtudo.com.br/tudo-sobre/redmi-note-10/
# Link: https://www.techtudo.com.br/jogos/
# Link: https://www.techtudo.com.br/jogos/jogos-casuais/
# Link: https://www.techtudo.com.br/jogos/jogos-de-esporte/
# Link: https://www.techtudo.com.br/jogos/jogos-de-acao/jogos-de-terror/
# Link: https://www.techtudo.com.br/jogos/jogos-de-acao/
# Link: https://www.techtudo.com.br/jogos/jogos-de-arcade/
# Link: https://www.techtudo.com.br/jogos/jogos-de-aventura/
# Link: https://www.techtudo.com.br/jogos/jogos-de-corrida/
# Link: https://www.techtudo.com.br/jogos/jogos-de-estrategia/
# Link: https://www.techtudo.com.br/jogos/jogos-de-luta/
# Link: https://www.techtudo.com.br/jogos/jogos-de-raciocinio/
# Link: https://www.techtudo.com.br/jogos/jogos-de-rpg/
# Link: https://www.techtudo.com.br/jogos/jogos-de-carta-e-tabuleiro/
# Link: https://www.techtudo.com.br/jogos/jogos-educativos/
# Link: https://www.techtudo.com.br/jogos/consoles/playstation/
# Link: https://www.techtudo.com.br/jogos/consoles/nintendo/
# Link: https://www.techtudo.com.br/jogos/consoles/nintendo/
# Link: https://forum.techtudo.com.br/tags/jogos/?utm_source=techtudo.com&utm_medium=referral&utm_campaign=site
# Link:
# Link: https://www.techtudo.com.br/tudo-sobre/grand-theft-auto-5/
# Link: https://www.techtudo.com.br/tudo-sobre/roblox/
# Link: https://www.techtudo.com.br/tudo-sobre/minecraft/
# Link: https://www.techtudo.com.br/e-sports/
# Link: https://www.techtudo.com.br/e-sports/campeonatos/
# Link: https://www.techtudo.com.br/e-sports/times/
# Link: https://www.techtudo.com.br/e-sports/atletas/
# Link:
# Link: https://www.techtudo.com.br/tudo-sobre/cblol/
# Link: https://www.techtudo.com.br/tudo-sobre/free-fire-pro-league-brazil/
# Link: https://www.techtudo.com.br/tudo-sobre/twitchtv/
# Link: https://www.techtudo.com.br/informatica/
# Link: https://www.techtudo.com.br/informatica/computadores/
# Link: https://www.techtudo.com.br/informatica/computadores/pc-gamer/
# Link: https://www.techtudo.com.br/informatica/notebooks/
# Link: https://www.techtudo.com.br/informatica/notebooks-2-em-1/
# Link: https://www.techtudo.com.br/informatica/notebooks/notebook-gamer/
# Link: https://www.techtudo.com.br/informatica/impressoras/
# Link: https://www.techtudo.com.br/informatica/impressoras/impressoras-3d/
# Link: https://www.techtudo.com.br/informatica/mouses/
# Link: https://www.techtudo.com.br/informatica/placas/
# Link: https://www.techtudo.com.br/informatica/roteadores/
# Link:
# Link: https://www.techtudo.com.br/tudo-sobre/windows-11/
# Link: https://www.techtudo.com.br/tudo-sobre/macos/
# Link: https://www.techtudo.com.br/tudo-sobre/linux.html
# Link: https://www.techtudo.com.br/eletronicos/
# Link: https://www.techtudo.com.br/eletronicos/caixas-de-som/
# Link: https://www.techtudo.com.br/eletronicos/cameras/
# Link: https://www.techtudo.com.br/eletronicos/filmadoras/
# Link: https://www.techtudo.com.br/eletronicos/veiculos/carros-smart/
# Link: https://www.techtudo.com.br/eletronicos/fones-de-ouvido/
# Link: https://www.techtudo.com.br/eletronicos/maquinas-de-cartao/
# Link: https://www.techtudo.com.br/eletronicos/media-centers/
# Link: https://www.techtudo.com.br/eletronicos/tvs/
# Link: https://www.techtudo.com.br/eletronicos/veiculos/
# Link:
# Link: https://www.techtudo.com.br/tudo-sobre/gopro-hero-2018/
# Link: https://www.techtudo.com.br/tudo-sobre/chromecast.html
# Link: https://www.techtudo.com.br/tudo-sobre/amazon-echo-dot/
# Link: https://www.techtudo.com.br/softwares/
# Link: https://www.techtudo.com.br/softwares/apps/
# Link: https://www.techtudo.com.br/softwares/apps/audio-e-video/
# Link: https://www.techtudo.com.br/softwares/apps/imagens/
# Link: https://www.techtudo.com.br/softwares/apps/internet/
# Link: https://www.techtudo.com.br/softwares/apps/produtividade/
# Link: https://www.techtudo.com.br/softwares/apps/redes-sociais/
# Link: https://www.techtudo.com.br/softwares/apps/seguranca/
# Link: https://www.techtudo.com.br/softwares/apps/utilitarios/
# Link:
# Link: https://www.techtudo.com.br/tudo-sobre/whatsapp-messenger/
# Link: https://www.techtudo.com.br/tudo-sobre/instagram/
# Link: https://www.techtudo.com.br/tudo-sobre/facebook.html
# Link: https://www.techtudo.com.br/tudo-sobre/youtube.html
# Link: https://www.techtudo.com.br/streaming/
# Link: https://www.techtudo.com.br/streaming/animes/
# Link: https://www.techtudo.com.br/streaming/series/
# Link: https://www.techtudo.com.br/streaming/filmes/
# Link: https://www.techtudo.com.br/streaming/programas-de-tv/
# Link: https://www.techtudo.com.br/streaming/plataformas-de-streaming/
# Link:
# Link: https://www.techtudo.com.br/mobile/telefonia/5g/
# Link: https://www.techtudo.com.br/eletronicos/casas-inteligentes/
# Link: https://www.techtudo.com.br/informatica/bitcoin-e-moedas-virtuais/
# Link: https://www.techtudo.com.br/eletronicos/qual-comprar/
# Link: https://www.techtudo.com.br/eventos/semana-do-consumidor/
# Link:
# Link: https://forum.techtudo.globo.com/
# Link: https://compare.techtudo.com.br/
# Link: https://www.techtudo.com.br/termos-de-uso/
# Link: https://privacidade.globo.com/privacy-policy/
# Link: /
# Link: https://www.techtudo.com.br
# Link: https://www.techtudo.com.br/ultimas/
# Link: https://www.techtudo.com.br/softwares/apps/
# Link: https://www.techtudo.com.br/mobile/
# Link: https://www.techtudo.com.br/jogos/
# Link: https://www.techtudo.com.br/e-sports/
# Link: https://www.techtudo.com.br/eletronicos/
# Link: https://www.techtudo.com.br/informatica/
# Link: https://www.techtudo.com.br/softwares/
# Link: https://www.techtudo.com.br/streaming/
# Link: https://www.techtudo.com.br/playlist/videos-techtudo/
# Link: https://id.globo.com/auth/realms/globo.com/protocol/openid-connect/auth?client_id=app-techtudo-forum%40globoid-connect&state=505e0625-707a-48a2-8ab8-5dd6a6bfb2e3&redirect_uri=https%3A%2F%2Fforum.techtudo.globo.com%2Flogin%2Fcallback&response_type=code&scope=openid
# Link: https://id.globo.com/auth/realms/globo.com/protocol/openid-connect/auth?client_id=app-techtudo-forum%40globoid-connect&state=505e0625-707a-48a2-8ab8-5dd6a6bfb2e3&redirect_uri=https%3A%2F%2Fforum.techtudo.globo.com%2Flogin%2Fcallback&response_type=code&scope=openid
# Link: /
# Link: https://id.globo.com/auth/realms/globo.com/protocol/openid-connect/auth?client_id=app-techtudo-forum%40globoid-connect&state=505e0625-707a-48a2-8ab8-5dd6a6bfb2e3&redirect_uri=https%3A%2F%2Fforum.techtudo.globo.com%2Flogin%2Fcallback&response_type=code&scope=openid
# Link: /minhas-perguntas
# Link: /minhas-respostas
# Link: /trofeus
# Link: /pergunte
# Link: /usuarios
# Link: /pergunte
# Link: /usuarios/135443/ftfh625
# Link: /usuarios/135443/ftfh625
# Link: /perguntas/647027/healthprofessions2escience2eoregonstate2eedusiteshealthprofessions2escience2eoregonstate2eedufilesey8k2epdf
# Link: /tags/jogos
# Link: /tags/facebook
# Link: /tags/ntfs
# Link: /usuarios/135443/ftfh625
# Link: /usuarios/135443/ftfh625
# Link: /perguntas/647026/healthprofessions2escience2eoregonstate2eedusiteshealthprofessions2escience2eoregonstate2eedufileszzxr42epdf
# Link: /tags/ajuda
# Link: /tags/placadevideo
# Link: /tags/windows
# Link: /usuarios/134999/mbo520
# Link: /usuarios/134999/mbo520
# Link: /perguntas/647025/bitbucket2eorgsnakeyamlsnakeyamlissues603voir-scream-6-en-streaming-vf-en-fran-ais
# Link: /tags/windows
# Link: /tags/whatsapp
# Link: /tags/hardware
# Link: /usuarios/134999/mbo520
# Link: /usuarios/134999/mbo520
# Link: /perguntas/647024/bitbucket2eorgsnakeyamlsnakeyamlissues605voir-scream-6-streaming-vf-fran-ais
# Link: /tags/smartphone
# Link: /tags/notebook
# Link: /tags/windows
# Link: /usuarios/135443/ftfh625
# Link: /usuarios/135443/ftfh625
# Link: /perguntas/647023/healthprofessions2escience2eoregonstate2eedusiteshealthprofessions2escience2eoregonstate2eedufilesyi2d2epdf
# Link: /tags/jogos
# Link: /tags/samsung
# Link: /tags/fotos
# Link: /usuarios/134999/mbo520
# Link: /usuarios/134999/mbo520
# Link: /perguntas/647022/bitbucket2eorgsnakeyamlsnakeyamlissues607voir-scream-vi-en-streaming-vf-en-fran-ais
# Link: /tags/windows
# Link: /tags/whatsapp
# Link: /tags/hardware
# Link: /usuarios/134999/mbo520
# Link: /usuarios/134999/mbo520
# Link: /perguntas/647021/bitbucket2eorgsnakeyamlsnakeyamlissues608voir-scream-6-films-en-streaming-complet
# Link: /tags/notebook
# Link: /tags/internet
# Link: /tags/problema
# Link: /usuarios/135443/ftfh625
# Link: /usuarios/135443/ftfh625
# Link: /perguntas/647020/healthprofessions2escience2eoregonstate2eedusiteshealthprofessions2escience2eoregonstate2eedufilesxyk72epdf
# Link: /tags/jogos
# Link: /tags/escolha
# Link: /tags/nfs
# Link: /usuarios/126853/lfan606
# Link: /usuarios/126853/lfan606
# Link: /perguntas/647019/bitbucket2eorgsnakeyamlsnakeyamlissues670
# Link: /tags/smartphone
# Link: /tags/jogos
# Link: /tags/samsung
# Link: /usuarios/135443/ftfh625
# Link: /usuarios/135443/ftfh625
# Link: /perguntas/647018/healthprofessions2escience2eoregonstate2eedusiteshealthprofessions2escience2eoregonstate2eedufileswf2y2epdf
# Link: /tags/smartphone
# Link: /tags/aplicativos
# Link: /tags/facebook
# Link: /usuarios/120732/wsma184
# Link: /usuarios/120732/wsma184
# Link: /perguntas/647017/bitbucket2eorgsnakeyamlsnakeyamlissues739
# Link: /tags/smartphone
# Link: /tags/jogos
# Link: /tags/samsung
# Link: /usuarios/128578/ogil906
# Link: /usuarios/128578/ogil906
# Link: /perguntas/647016/httpsbitbucketorgsnakeyamlsnakeyamlissues737watch-the-last-scream-fullmovie-online
# Link: /tags/aplicativos
# Link: /tags/computador
# Link: /tags/placadevideo
# Link: /usuarios/133388/ion933
# Link: /usuarios/133388/ion933
# Link: /perguntas/647015/bitbucket2eorgsnakeyamlsnakeyamlissues611voir-scream-vi-en-streaming-vf-en-fran-ais
# Link: /tags/jogos
# Link: /tags/samsung
# Link: /tags/ios
# Link: /usuarios/133388/ion933
# Link: /usuarios/133388/ion933
# Link: /perguntas/647014/bitbucket2eorgsnakeyamlsnakeyamlissues613voir-scream-6-films-en-streaming-complet
# Link: /tags/smartphone
# Link: /tags/jogos
# Link: /tags/samsung
# Link: /usuarios/133388/ion933
# Link: /usuarios/133388/ion933
# Link: /perguntas/647013/bitbucket2eorgsnakeyamlsnakeyamlissues614voir-creed-iii-en-streaming-vf-en-fran-ais
# Link: /tags/jogos
# Link: /tags/samsung
# Link: /tags/ios
# Link: https://www.techtudo.com.br/softwares/apps/
# Link: https://www.techtudo.com.br/tudo-sobre/instagram/
# Link: https://www.techtudo.com.br/tudo-sobre/whatsapp-messenger/
# Link: https://www.techtudo.com.br/tudo-sobre/youtube/
# Link: https://www.techtudo.com.br/mobile/
# Link: https://www.techtudo.com.br/tudo-sobre/iphone-14/
# Link: https://www.techtudo.com.br/tudo-sobre/android/
# Link: https://www.techtudo.com.br/tudo-sobre/ios/
# Link: http://www.techtudo.com.br/jogos
# Link: https://www.techtudo.com.br/tudo-sobre/coin-master/
# Link: https://www.techtudo.com.br/tudo-sobre/grand-theft-auto-5/
# Link: https://www.techtudo.com.br/tudo-sobre/minecraft/
# Link: https://www.techtudo.com.br/e-sports/
# Link: https://www.techtudo.com.br/tudo-sobre/counter-strike-global-offensive/
# Link: https://www.techtudo.com.br/tudo-sobre/league-of-legends/
# Link: https://www.techtudo.com.br/tudo-sobre/valorant/
# Link: https://www.techtudo.com.br/eletronicos/
# Link: https://www.techtudo.com.br/tudo-sobre/amazon-echo-dot/
# Link: https://www.techtudo.com.br/tudo-sobre/chromecast/
# Link: https://www.techtudo.com.br/tudo-sobre/gopro-hero-2018/
# Link: https://www.techtudo.com.br/informatica/
# Link: https://www.techtudo.com.br/tudo-sobre/intel-core-i5/
# Link: https://www.techtudo.com.br/softwares/
# Link: https://www.techtudo.com.br/tudo-sobre/adobe-photoshop/
# Link: https://www.techtudo.com.br/tudo-sobre/adobe-reader/
# Link: https://www.techtudo.com.br/tudo-sobre/windows/
# Link: https://www.techtudo.com.br/streaming/
# Link: https://www.techtudo.com.br/tudo-sobre/a-casa-do-dragao/
# Link: https://www.techtudo.com.br/tudo-sobre/stranger-things/
# Link: https://www.techtudo.com.br/tudo-sobre/wandinha/
# Link: https://privacidade.globo.com/privacy-policy/
# Link: https://meuperfil.globo.com/
# Link: https://anuncie.globo.com/mediakit/globocom.html
# Link: https://id.globo.com/auth/realms/globo.com/protocol/openid-connect/auth?client_id=app-techtudo-forum%40globoid-connect&state=505e0625-707a-48a2-8ab8-5dd6a6bfb2e3&redirect_uri=https%3A%2F%2Fforum.techtudo.globo.com%2Flogin%2Fcallback&response_type=code&scope=openid
# Link: /
# Link: /pergunte
# Link: https://id.globo.com/auth/realms/globo.com/protocol/openid-connect/auth?client_id=app-techtudo-forum%40globoid-connect&state=505e0625-707a-48a2-8ab8-5dd6a6bfb2e3&redirect_uri=https%3A%2F%2Fforum.techtudo.globo.com%2Flogin%2Fcallback&response_type=code&scope=openid
# Link: https://id.globo.com/auth/realms/globo.com/protocol/openid-connect/auth?client_id=app-techtudo-forum%40globoid-connect&state=505e0625-707a-48a2-8ab8-5dd6a6bfb2e3&redirect_uri=https%3A%2F%2Fforum.techtudo.globo.com%2Flogin%2Fcallback&response_type=code&scope=openid
# Link: https://id.globo.com/auth/realms/globo.com/protocol/openid-connect/auth?client_id=app-techtudo-forum%40globoid-connect&state=505e0625-707a-48a2-8ab8-5dd6a6bfb2e3&redirect_uri=https%3A%2F%2Fforum.techtudo.globo.com%2Flogin%2Fcallback&response_type=code&scope=openid
# Link: /minhas-perguntas
# Link: /minhas-respostas
# Link: /trofeus
# Link: /usuarios
# Fim da coleta
# Quantidade de páginas coletadas:  34
# Quantidade de URLS:  4606
# Tempo total:  6.861939191818237

# %% [markdown]
# # Bibliografia
#
# Baeza-Yates, Ricardo; Ribeiro-Neto, Berthier. **Modern information retrieval: the concepts and technology behind search**. ACM Press, 2011.
#
# Batista, Natércia ; Brandão, Michele ; Pinheiro, Michele ; Dalip, Daniel ; Moro, Mirella . **[Dados de Múltiplas Fontes da Web: coleta, integração e pré-processamento](https://sol.sbc.org.br/livros/index.php/sbc/catalog/download/8/19/58-1?inline=1)**. Minicursos do XXIV Simpósio Brasileiro de Sistemas Multimídia e Web. 1ed.: Sociedade Brasileira de Computação, 2018, v. , p. 153-192.
