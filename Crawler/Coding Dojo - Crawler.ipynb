# %% [markdown]
# # ☯ Coding Dojo ☯

# %% [markdown]
# <img style="float:left" src="imgs/vamos_coletar.png">
# ## Regras
#
# Ponto de participação, poderá perdido se:
#
#     - Aluno atrasado (ver política de atraso na especificação)
#     - Recusar participação como piloto/copiloto
#         - Ou não querer sair do computador, quando solicitado :-)
#     - Demorar para sair quando solicitado
#     - Parar de participar por:
#         - Uso de outro computador
#         - Uso de celular
#         - Usar a internet
#         - Conversa

# %% [markdown]
# Antes de entregar, certifique-se que tenha executado todos os comandos/códigos deste Jupyter. É obrigatório que todas as saídas tenham sido apresentadas. Perda de 3 pontos caso não tenham feito isso.

# %% [markdown]
# # Dependencias

# %% [markdown]
# Se necessário, instale o python3 e o pip3 abaixo usando `sudo apt-get install python3 python3-pip`.  Execute abaixo para instalar o [BeautifulSoup](https://www.crummy.com/software/BeautifulSoup/) e o [lxml](https://lxml.de/). Qualquer linha de comando/código como a de baixo, você pode executá-la a selecionando e pressionando `ctrl+enter` ❣️.

# %%
# !pip3 install bs4
# !pip3 install lxml
# Out:
# Requirement already satisfied: bs4 in h:\development\python\python 3.11.2\lib\site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in h:\development\python\python 3.11.2\lib\site-packages (from bs4) (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in h:\development\python\python 3.11.2\lib\site-packages (from beautifulsoup4->bs4) (2.4)
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: lxml in h:\development\python\python 3.11.2\lib\site-packages (4.9.2)
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Caso de comando não encontrado `pip3` use `pip`.

# %% [markdown]
# # Coletor

# %% [markdown]
# <img src="imgs/arquitetura_coletor.png">

# %% [markdown]
# Você deverá completar a implementação das três classes abaixo para fazer o coletor: `Domain`, `Scheduler` e `PageFetcher`. Conforme figura acima, o `Scheduler` é responsável por armazenar as filas de URLs a serem requisitadas; o PageFetcher serão *threads* responsáveis por fazer as requisições das URLs obtidas por meio do escalonador (instancia da classe `Scheduler`). A classe `Domain` armazena informações importantes sobre o servidor a serem usadas no momento do escalonamento das URLs.

# %% [markdown]
# ## Classe `Domain`

# %% [markdown]
# <figure style="text-align:center">
#     <img src="imgs/estrutura_coletor.png">
#     <caption>Fonte: Baeza-Yates e Ribeiro-Neto, 2011 </caption>
# </figure>

# %% [markdown]
# Antes de começar a fazer o escalonador (classe `Scheduler`) devemos implementar a classe que representa os domínios. Conforme visto na figura acima, o escalonador possuirá diversas filas, uma para cada servidor.  Em nosso caso, o servidor será um domínio - que você irá implementar na classe `Domain` do arquivo `domain.py`.
#
# O escalonador percorrerá cada servidor e obterá o primeiro da fila do primeiro servidor acessível. O servidor é acessível obdecendo o limite de tempo entre requisições (em segundos, usando o atributo `time_limit_between_requests`).
#
# Nesta atividade você irá implementar a classe `Domain`, que já possui os seguintes atributos:
#
# - *time_limit_between_requests*: Limite entre requisições (int)
# - *nam_domain*: Nome do domínio (String)
# - *time_last_access*: [Objeto Datetime](https://docs.python.org/3/library/datetime.html#datetime-objects) informando da data/hora do último acesso
#
# O prefixo da variável sempre irá denotar o tipo da mesma.

# %% [markdown]
# **Atividade 1 - classe `Domain`**: Complete a classe `Domain` implementando os métodos/atributos calculados descritos a seguir. Logo após, execute o ❣️ teste unitário ❣️ para verificar se os métodos/atributos calculados foram implementados conforme esperado.
#
# - **accessed_now**: Método que modifica o último acesso com a data/hora atual usando um [objeto datetime](https://docs.python.org/3/library/datetime.html#datetime-objects)
# - **time_since_last_access**: Atributo calculado que retorna um [objeto TimeDelta](https://docs.python.org/3/library/datetime.html#timedelta-objects) com a diferença da data atual e a data do último acesso. Veja os exemplos de uso do TimeDelta na sua documentação
# - **is_accessible**: Método que verdadeiro se o domínio estiver acessível

# %% [markdown]
# Os métodos `count_fetched_page` e `has_finished_crawl` já estão implementados. Execute o teste unitário a seguir. Veja que o comando abaixo executa o teste unitário presente no arquivo `crawler/scheduler_test.py`. Analise-o para entender como implementamos testes unitários.

# %%
# !python -m crawler.scheduler_test DomainTest.test_domain
# Out:
# Verificando acesso a um dominio já requisitado (após espera)
# aguardando 10 segundos...
# .
# ----------------------------------------------------------------------
# Ran 1 test in 10.001s
#
# OK

# %% [markdown]
# **Atividade 2 - métodos `__hash__` e `__eq__` da classe `Domain`**: A fila será implementada por um dicionario ordenado ([OrderedDict](https://docs.python.org/2/library/collections.html#collections.OrderedDict)) em que a chave será um objeto da classe domínio e o valor serão uma lista de URLs. Para que seja possível a busca do domínio, você deverá implementar os métodos `__hash__` e `__eq__` de forma similar ao seguinte exemplo:

# %%
from collections import OrderedDict
class Xuxu():
    def __str__(self):
        return "xuxuuu"
    
    def __hash__(self):
        return hash("xuxu")
    def __eq__(self, x):
        return x == "xuxu"
d = OrderedDict()
d[Xuxu()] = 'A'
print("xuxu" in d)
# Out:
# True

# %% [markdown]
# No nosso caso, deve ser permitido fazer a busca no dicionário pelo nome do domínio ou pelo objeto, ou seja, após a implementação desta atividade, o seguinte código irá funcionar corretamente:

# %%
from crawler.domain import Domain
from collections import OrderedDict

obj_domain = Domain("oi.com",10)
dic_x = OrderedDict()
dic_x[obj_domain] = "lala"
dic_x["oi.com"] = "oi"

#abaixo, em ambos os casos, será encontrado/impresso a string "oi"
print(dic_x["oi.com"])
print(dic_x[obj_domain])
# Out:
# oi
# oi

# %% [markdown]
# Lembre-se que, em nosso caso, o parametro do método `__eq__` pode ser um objeto da classe `Domain` ou uma string representando o nome do domínio. Caso faça alguma modificação no código, você deverá reiniciar o kernel para que o efeito seja visto no código acima (para reiniciar, clique em Kernel->Restart). Isso ocorre que, uma vez dado import em um módulo, esse modulo não é alterado no Jupyter caso você faça uma modificação no código.

# %% [markdown]
# ## Classe `Scheduler`

# %% [markdown]
# Agora você irá implementar o escalonador. Essa classe será responsável por gerir as URLs.
# Para isso, será implementado as filas por servidores conforme apresentado na figura da seção anterior.
# Para isso, utilizaremos um OrderedDict em que as chaves são os servidores (objeto da classe `Domain`) e o valor será uma lista de tuplas com as URLs e sua profundidade. Com o objetivo de armazenar as URLs de forma estruturada, as mesmas **não serão** string, ao invés disso, serão objetos da classe `ParseResult` - essa classe é retornada do método [urlparse](https://docs.python.org/3/library/urllib.parse.html). Veja um exemplo abaixo.

# %%
from crawler.domain import Domain
from crawler.scheduler import Scheduler
from urllib.parse import urlparse

dict_filas_por_servidor = {Domain("www.globo.com",10):[
                                                (urlparse("http://www.globo.com/esporte"),1),
                                                (urlparse("http://www.globo.com/noticia_um"),2),
                                                (urlparse("http://www.globo.com/noticia_dois"),3),
                                                (urlparse("http://www.globo.com/noticia_tres"),3),
                                                ],
                            Domain("www.cnpq.br",10):[(urlparse("http://www.cnpq.br/pesquisadores"),1),
                                               (urlparse("http://www.cnpq.br/bolsas"),1)]
                          }

# %% [markdown]
# Assim, a classe `Scheduler`, no arquivo `scheduler.py` possui os seguintes atributos:
#
# - `str_usr_agent`: Nome do `User agent`. Usualmente, é o nome do navegador, no nosso caso, será o nome do coletor (usualmente, terminado em `bot`)
# - `page_limit`: Número de páginas a serem coletadas
# - `depth_limit`: Profundidade máxima a ser coletada
# - `page_count`: Quantidade de páginas já coletadas
# - `dic_url_per_domain`: Fila de URLs por domínio (explicado anteriormente)
# - `set_discovered_urls`: Conjunto de URLs descobertas, ou seja, que foi extraída em algum HTML e já adicionadas na fila - mesmo se já ela foi retirada da fila. A URL armazenada deve ser uma string.
# - `dic_robots_per_domain`: Dicionário armazenando, para cada domínio, o objeto representando as regras obtidas no `robots.txt`

# %% [markdown]
# **Atividad 3 - Método `can_add_page`**: Esse método irá retornar verdadeiro caso seja possível adicionar a página `obj_url` (objeto da classe ParseResult) que foi coletada na profundidade `depth`. Para que seja possível adicionar na lista, esta pagina não deve ter sido descoberta e nem com a profundidade maior que o limite. Este método será testado por teste unitário apenas após a implementação da adição e obtenção das URLs.

# %% [markdown]
# **Atividade 4 método `add_new_page` - Adicionar nova página**:  Este método retorna falso caso não seja possível adicionar a página (por meio do método `can_add_page`) e verdadeiro, caso contrário. Caso seja possível, deve-se adicionar a url `obj_url` na fila `dic_url_per_domain`. Lembre-se da estrutura do dicionário `dic_url_per_domain`. Não esqueça de armazenar que esta URL já foi descoberta. Este método será testado por teste unitário apenas após a implementação da obtenção das URLs. Lembre-se de como trabalhar com [dicionários](https://daniel-hasan.github.io/cefet-web-grad/classes/python2/#mais-colecoes)

# %% [markdown]
# **Atividade 5 método `get_next_url` - obtém a próxima URL da fila**: Este método retona uma tupla `url,profundade` da próxima URL a ser coletada por meio da fila `dic_url_per_domain` retirando este item da fila. Lembre-se que:
#
# - Ele deverá retornar a primeira URL do primeiro servidor que estiver acessível.
# - Você deve indicar que o servidor foi acessado
# - Caso a fila deste servidor esteja vazia, elimine-o do dicionário
# - Caso não encontre a URL, [coloque a Thread para esperar](https://docs.python.org/2/library/time.html#time.sleep) e, logo após, procure novamente
#
# Logo após, você já pode executar o teste unitário para verificar se a obtenção e adição de URLs está correta. Caso haja algum problema, existem já alguns prints comentados no código, descomente-os para verificar se o fluxo está ocorrendo da forma correta. Você deverá entregar sem a exibição desses prints (caso contrário, perderá pontos).

# %%
# !python -m crawler.scheduler_test SchedulerTest.test_add_remove_page
# Out:
# Verificação da ordem das URLs...
# Resgatando a segunda página do mesmo dominio...
# Tempo esperado: 20 segundos
# .
# ----------------------------------------------------------------------
# Ran 1 test in 20.001s
#
# OK

# %% [markdown]
# **Atividade 6 método `can_fetch_page`**: Este método deve retornar verdadeiro caso a url (Objeto `ParseResult`), passada como parâmetro, pode ser coletada de acordo com o `Robots.txt` do domínio. Para isso, você deve usar o [`RobotFileParser`](https://docs.python.org/3/library/urllib.robotparser.html) para requisitar a URL do `robots.txt` deste domínio. Por razões de performance, você só poderá requisitar o robots.txt uma única vez por domínio. Assim, use o `dic_robots_per_domain` apropriadamente. Execute o teste unitário abaixo para verificar seu funcionamento.

# %%
# !python -m crawler.scheduler_test SchedulerTest.test_can_fetch
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.280s
#
# OK

# %% [markdown]
# **Atividade 7 - Inicialização das sementes no construtor**: No construtor da classe `Scheduler` você deve adicionar as páginas sementes na fila. Tais sementes são passadas pelo parametro `arr_urls_seeds` do construtor.

# %%
# !python -m crawler.scheduler_test SchedulerTest.test_init
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.000s
#
# OK

# %% [markdown]
# Logo após, utize a anotação @synchronized aonde julgar necessário para transformar em ThreadSafe.

# %% [markdown]
# ## PageFetcher

# %% [markdown]
# **Atividade 8 - Efetuar a requisição - método `request_url`:** Neste método você irá fazer a requisição usando a api [requests](https://requests.readthedocs.io/en/master/). Além disso, deve-se informar no cabeçalho (em `User-Agent`) o nome do coletor. O método deverá retornar o conteúdo (em binário) apenas se o conteúdo for HTML (ver no cabeçalho da resposta o tipo do conteúdo). Caso não seja, ele deverá retornar `None`.

# %%
# !python -m crawler.page_fetcher_test PageFetcherTest.test_request_url
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 1.102s
#
# OK

# %% [markdown]
# **Atividade 9 extração das URLs por meio do método `discover_links`**: A partir do conteúdo (texto em binário) `bin_str_content` deve-se extrair seus os links. O conteúdo esta em binário, pois, o BeautifulSoup, internamente, verifica o encoding por meio da [tag meta](https://www.w3schools.com/tags/att_meta_charset.asp) e converte para UTF8. A URL da página coletada é um objeto ParseResult `obj_url` que está na profundidade `depth`.
#
# Para cada URL extraída, você deverá retornar uma tupla com a URL (objeto ParseResult) e a sua profundidade. Utilize o comando `yield` para retornar essas tuplas. A profundidade é calculada de por meio de  `obj_url` e `depth`, conforme comentado em sala de aula.
#
# Para a extração dos links, use o [CSS Selector do BeautifulSoup](https://www.crummy.com/software/BeautifulSoup/bs4/doc/#css-selectors). Seletor CSS é uma expressão que define quais elementos HTML serão estilizados pelo CSS. No *Beatifulsoup* eles são usados para selecionar quais tags serão extraídas. Veja o exemplo de uso e brinque abaixo. Caso precise, veja aqui um pouco de seletores CSS: [slides de Web](https://fegemo.github.io/cefet-front-end/classes/css2/#outros-seletores), [documentação MDN](https://developer.mozilla.org/en-US/docs/Web/CSS/CSS_Selectors).

# %%
from bs4 import BeautifulSoup

# %%
# !python -m crawler.page_fetcher_test PageFetcherTest.test_discover_links
# Out:
# Simulação da extração de links da página http://www.pudim.com.br na profundidade nível 2...
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.002s
#
# OK

# %% [markdown]
# **Atividade 10 - método que solicita uma nova URL**: Por meio do método `crawl_new_url` você deverá utilizar os métodos previamente implementados para:
#
# - Solicitar ao escalonador uma nova URL
# - Fazer a requisição e obter o resultado (em binário)
# - Caso a URL seja um HTML válido, imprima esta URL e extraia os seus links

# %% [markdown]
# **Atividade 11 - método run**: Este método deve coletar páginas enquanto a coleta não foi finalizada

# %% [markdown]
# **Atividade 12 - um pequeno teste para finalizar:** Use as sementes do seu grupo e crie abaixo um escalonador e 5 PageFetchers para extrair 30 páginas. Imprima também o tempo gasto total.

# %%
from tests.crawler_tests import main_test_crawler

main_test_crawler()
# Out:
# URL: http://www.globo.com/
# Arquivo salvo em: pages/www.globo.com#.txt
# URL: http://www.cnpq.br/
# Arquivo salvo em: pages/www.cnpq.br#.txt
# URL: http://www.uol.com.br/
# Arquivo salvo em: pages/www.uol.com.br#.txt
# URL: https://www.uai.com.br/
# Arquivo salvo em: pages/www.uai.com.br#.txt
# URL: https://www.terra.com.br/
# Arquivo salvo em: pages/www.terra.com.br#.txt
# URL: https://www.bbc.com/
# Arquivo salvo em: pages/www.bbc.com#.txt
# URL: https://www.tecmundo.com.br/
# Arquivo salvo em: pages/www.tecmundo.com.br#.txt
# URL: https://www.olhardigital.com.br/
# Arquivo salvo em: pages/www.olhardigital.com.br#.txt
# URL: https://www.em.com.br/
# Arquivo salvo em: pages/www.em.com.br#.txt
# URL: https://www.estadao.com.br/
# Arquivo salvo em: pages/www.estadao.com.br#.txt
# Error: <urlopen error [Errno 11001] getaddrinfo failed>
# URL: https://minhaconta.globo.com
# Arquivo salvo em: pages/minhaconta.globo.com.txt
# Error: <urlopen error [WinError 10054] An existing connection was forcibly closed by the remote host>
# URL: https://g1.globo.com/?utm_source=globo.com&utm_medium=menuburguer
# Arquivo salvo em: pages/g1.globo.com##utm_source=globo.com#utm_medium=menuburguer.txt
# URL: https://www.gazetadopovo.com.br/
# Arquivo salvo em: pages/www.gazetadopovo.com.br#.txt
# URL: https://valor.globo.com/?utm_source=globo.com&utm_medium=menuburguer
# Arquivo salvo em: pages/valor.globo.com##utm_source=globo.com#utm_medium=menuburguer.txt
# URL: https://vitrine.globo.com/assine/globoplay-canais?origemId=1760&utm_source=gcom&utm_medium=menuburguer&utm_campaign=gcom-logo-menu
# Arquivo salvo em: pages/vitrine.globo.com#assine#globoplay-canais#origemId=1760#utm_source=gcom#utm_medium=menuburguer#utm_campaign=gcom-logo-menu.txt
# URL: https://ge.globo.com/cartola/?utm_source=globocom&utm_medium=menuburguer&utm_campaign=c2022_10_cartola_cartola-2022_alcance&utm_content=MEN_cartola-2022
# Arquivo salvo em: pages/ge.globo.com#cartola##utm_source=globocom#utm_medium=menuburguer#utm_campaign=c2022_10_cartola_cartola-2022_alcance#utm_content=MEN_cartola-2022.txt
# URL: https://globoesporte.globo.com/?utm_source=globo.com&utm_medium=menuburguer
# Arquivo salvo em: pages/globoesporte.globo.com##utm_source=globo.com#utm_medium=menuburguer.txt
# URL: https://gshow.globo.com/?utm_source=globo.com&utm_medium=menuburguer
# Arquivo salvo em: pages/gshow.globo.com##utm_source=globo.com#utm_medium=menuburguer.txt
# URL: https://revistaquem.globo.com/?utm_source=globo.com&utm_medium=menuburguer
# Arquivo salvo em: pages/revistaquem.globo.com##utm_source=globo.com#utm_medium=menuburguer.txt
# URL: https://receitas.globo.com/?utm_source=globo.com&utm_medium=menuburguer
# Arquivo salvo em: pages/receitas.globo.com##utm_source=globo.com#utm_medium=menuburguer.txt
# URL: https://gigagloob.globo.com/assine/?origemId=2642&utm_source=globo.com&utm_medium=menuburguer
# Arquivo salvo em: pages/gigagloob.globo.com#assine##origemId=2642#utm_source=globo.com#utm_medium=menuburguer.txt
# URL: https://globoplay.globo.com/podcasts/categorias/podcasts-mais-ouvidos/?origemId=1760&utm_source=gcom&utm_medium=menuburguer&utm_campaign=gcom-logo-menu-podcast
# Arquivo salvo em: pages/globoplay.globo.com#podcasts#categorias#podcasts-mais-ouvidos##origemId=1760#utm_source=gcom#utm_medium=menuburguer#utm_campaign=gcom-logo-menu-podcast.txt
# URL: http://app.globoesporte.globo.com/futebol/publico-no-brasil/index.html
# Arquivo salvo em: pages/app.globoesporte.globo.com#futebol#publico-no-brasil#index.html.txt
# URL: http://especiais.g1.globo.com/educacao/app-g1-enem/
# Arquivo salvo em: pages/especiais.g1.globo.com#educacao#app-g1-enem#.txt
# URL: https://interativos.globoesporte.globo.com/futebol/rotatividade-dos-tecnicos
# Arquivo salvo em: pages/interativos.globoesporte.globo.com#futebol#rotatividade-dos-tecnicos.txt
# URL: https://valorinveste.globo.com/ferramentas/calculadoras/calculadora-salario-liquido/?utm_source=globocom&utm_medium=referral&utm_campaign=menulateral-globocom
# Arquivo salvo em: pages/valorinveste.globo.com#ferramentas#calculadoras#calculadora-salario-liquido##utm_source=globocom#utm_medium=referral#utm_campaign=menulateral-globocom.txt
# URL: https://www.techtudo.com.br/mobile/
# Arquivo salvo em: pages/www.techtudo.com.br#mobile#.txt
# URL: https://autoesporte.globo.com/
# Arquivo salvo em: pages/autoesporte.globo.com#.txt
# URL: https://extra.globo.com/
# Arquivo salvo em: pages/extra.globo.com#.txt
# URL: http://revistaepoca.globo.com/
# Arquivo salvo em: pages/revistaepoca.globo.com#.txt
# URL: http://epocanegocios.globo.com/
# Arquivo salvo em: pages/epocanegocios.globo.com#.txt
# URL: https://forum.techtudo.globo.com/
# Arquivo salvo em: pages/forum.techtudo.globo.com#.txt
# URL: https://globorural.globo.com/
# Arquivo salvo em: pages/globorural.globo.com#.txt
# URL: http://revistagalileu.globo.com/
# Arquivo salvo em: pages/revistagalileu.globo.com#.txt
# Error: URL can't contain control characters. 'cbn.globoradio.globo.com ' (found at least ' ')
# URL: https://bhfm.globo.com/
# Arquivo salvo em: pages/bhfm.globo.com#.txt
# URL: https://umsoplaneta.globo.com/
# Arquivo salvo em: pages/umsoplaneta.globo.com#.txt
# URL: https://radioglobo.globo.com/
# Arquivo salvo em: pages/radioglobo.globo.com#.txt
# URL: http://revistapegn.globo.com/
# Arquivo salvo em: pages/revistapegn.globo.com#.txt
# URL: http://casavogue.globo.com/
# Arquivo salvo em: pages/casavogue.globo.com#.txt
# URL: http://revistacasaejardim.globo.com/
# Arquivo salvo em: pages/revistacasaejardim.globo.com#.txt
# URL: https://www.terra.com.br/#trr-ctn-general
# Arquivo salvo em: pages/www.terra.com.br##trr-ctn-general.txt
# URL: https://www.globo.com/todos-os-sites/
# Arquivo salvo em: pages/www.globo.com#todos-os-sites#.txt
# URL: https://www.uai.com.br/publicidade/site/
# Arquivo salvo em: pages/www.uai.com.br#publicidade#site#.txt
# URL: https://www.globo.com/
# Arquivo salvo em: pages/www.globo.com#.txt
# Error: HTTPSConnectionPool(host='privacidade.globo.com', port=443): Max retries exceeded with url: /privacy-policy (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:992)')))
# URL: https://www.terra.com.br
# Arquivo salvo em: pages/www.terra.com.br.txt
# URL: https://www.uol.com.br/esporte/podcast/posse-de-bola/
# Arquivo salvo em: pages/www.uol.com.br#esporte#podcast#posse-de-bola#.txt
# Error: OrderedDict mutated during iteration
# URL: https://www.uai.com.br/entretenimento/
# Arquivo salvo em: pages/www.uai.com.br#entretenimento#.txt
# URL: http://www.cnpq.br/#wrapper
# URL: http://www.cnpq.br/#main-navigation
# Arquivo salvo em: pages/www.cnpq.br##wrapper.txt
# Arquivo salvo em: pages/www.cnpq.br##main-navigation.txt
# URL: https://www.bbc.com/#orb-modules
# Arquivo salvo em: pages/www.bbc.com##orb-modules.txt
# URL: http://www.cnpq.br/#govbr-busca-input
# Arquivo salvo em: pages/www.cnpq.br##govbr-busca-input.txt
# URL: https://www.em.com.br
# URL: https://www.estadao.com.br/ultimas
# Arquivo salvo em: pages/www.em.com.br.txt
# Arquivo salvo em: pages/www.estadao.com.br#ultimas.txt
# URL: https://www.olhardigital.com.br/editorias/noticias/
# Arquivo salvo em: pages/www.olhardigital.com.br#editorias#noticias#.txt
# URL: https://www.uol.com.br/podcasts/
# Arquivo salvo em: pages/www.uol.com.br#podcasts#.txt
# Error: OrderedDict mutated during iteration
# URL: https://minhaconta.globo.com/
# Arquivo salvo em: pages/minhaconta.globo.com#.txt
# URL: https://oglobo.globo.com/
# Arquivo salvo em: pages/oglobo.globo.com#.txt
# URL: https://g1.globo.com/previsao-do-tempo?utm_source=globo.com&utm_medium=menu&utm_campaign=previsao-do-tempo
# Arquivo salvo em: pages/g1.globo.com#previsao-do-tempo#utm_source=globo.com#utm_medium=menu#utm_campaign=previsao-do-tempo.txt
# URL: https://vitrine.globo.com/?origemId=1984&?utm_source=globo.com&utm_medium=menu
# Arquivo salvo em: pages/vitrine.globo.com##origemId=1984##utm_source=globo.com#utm_medium=menu.txt
# URL: https://valor.globo.com
# Arquivo salvo em: pages/valor.globo.com.txt
# URL: https://www.gazetadopovo.com.br/ultimas-noticias/
# Arquivo salvo em: pages/www.gazetadopovo.com.br#ultimas-noticias#.txt
# URL: https://ge.globo.com/cartola/?utm_source=globocom&utm_medium=header&utm_campaign=c2022_10_cartola_cartola-2022_alcance&utm_content=HEA_cartola-2022
# Arquivo salvo em: pages/ge.globo.com#cartola##utm_source=globocom#utm_medium=header#utm_campaign=c2022_10_cartola_cartola-2022_alcance#utm_content=HEA_cartola-2022.txt
# URL: https://gshow.globo.com/novelas/alem-da-ilusao/
# URL: https://globoesporte.globo.com/futebol/times/flamengo/
# Arquivo salvo em: pages/gshow.globo.com#novelas#alem-da-ilusao#.txt
# URL: http://www.globo.com/Portal/anuncie/glb_anuncie_panfleto
# Arquivo salvo em: pages/globoesporte.globo.com#futebol#times#flamengo#.txt
# URL: http://revistaquem.globo.com/
# Arquivo salvo em: pages/www.globo.com#Portal#anuncie#glb_anuncie_panfleto.txt
# Arquivo salvo em: pages/revistaquem.globo.com#.txt
# URL: https://receitas.globo.com/?utm_source=globo.com&utm_medium=header
# Arquivo salvo em: pages/receitas.globo.com##utm_source=globo.com#utm_medium=header.txt
# URL: https://gigagloob.globo.com/assine/?origemId=2641&utm_source=globo.com&utm_medium=header
# Arquivo salvo em: pages/gigagloob.globo.com#assine##origemId=2641#utm_source=globo.com#utm_medium=header.txt
# URL: http://app.globoesporte.globo.com/futebol/publico-no-brasil/time/flamengo/
# Arquivo salvo em: pages/app.globoesporte.globo.com#futebol#publico-no-brasil#time#flamengo#.txt
# URL: https://globoplay.globo.com/canais/bis/
# Arquivo salvo em: pages/globoplay.globo.com#canais#bis#.txt
# URL: http://especiais.g1.globo.com/newsletter/
# Arquivo salvo em: pages/especiais.g1.globo.com#newsletter#.txt
# URL: https://interativos.globoesporte.globo.com/futebol/mercado/vai-e-vem/vai-e-vem-do-mercado-2020
# URL: https://valorinveste.globo.com/ferramentas/comparador-de-investimentos/?utm_source=globocom&utm_medium=referral&utm_campaign=menulateral-globocom
# Arquivo salvo em: pages/interativos.globoesporte.globo.com#futebol#mercado#vai-e-vem#vai-e-vem-do-mercado-2020.txt
# Arquivo salvo em: pages/valorinveste.globo.com#ferramentas#comparador-de-investimentos##utm_source=globocom#utm_medium=referral#utm_campaign=menulateral-globocom.txt
# URL: https://www.techtudo.com.br/eletronicos/tvs/
# URL: https://autoesporte.globo.com/ultimas-noticias/
# Arquivo salvo em: pages/www.techtudo.com.br#eletronicos#tvs#.txt
# Arquivo salvo em: pages/autoesporte.globo.com#ultimas-noticias#.txt
# URL: https://extra.globo.com/tv-e-lazer/morto-aos-82-anos-antonio-pedro-sera-cremado-nesta-segunda-no-rio-rv1-1-25674414.html
# Arquivo salvo em: pages/extra.globo.com#tv-e-lazer#morto-aos-82-anos-antonio-pedro-sera-cremado-nesta-segunda-no-rio-rv1-1-25674414.html.txt
# URL: https://epocanegocios.globo.com/Empresa/noticia/2020/12/os-negocios-da-nossa-epoca-para-uma-nova-geracao-de-lideres-e-empresas-que-querem-mudar-o-mundo.html
# Arquivo salvo em: pages/epocanegocios.globo.com#Empresa#noticia#2020#12#os-negocios-da-nossa-epoca-para-uma-nova-geracao-de-lideres-e-empresas-que-querem-mudar-o-mundo.html.txt
# Error: OrderedDict mutated during iteration
# URL: http://revistaepoca.globo.com/#top
# Arquivo salvo em: pages/revistaepoca.globo.com##top.txt
# URL: https://globorural.globo.com/ultimas-noticias/
# Arquivo salvo em: pages/globorural.globo.com#ultimas-noticias#.txt
# URL: https://bhfm.globo.com/home/HOME.htm
# Arquivo salvo em: pages/bhfm.globo.com#home#HOME.htm.txt
# URL: http://radioglobo.globo.com/
# Arquivo salvo em: pages/radioglobo.globo.com#.txt
# URL: https://casavogue.globo.com/
# Arquivo salvo em: pages/casavogue.globo.com#.txt
# URL: https://umsoplaneta.globo.com/manifesto/noticia/2021/03/30/nosso-manifesto-1.ghtml
# Arquivo salvo em: pages/umsoplaneta.globo.com#manifesto#noticia#2021#03#30#nosso-manifesto-1.ghtml.txt
# URL: http://revistaglamour.globo.com/
# Arquivo salvo em: pages/revistaglamour.globo.com#.txt
# URL: http://gq.globo.com/
# Arquivo salvo em: pages/gq.globo.com#.txt
# URL: https://forum.techtudo.globo.com/minhas-perguntas
# Arquivo salvo em: pages/forum.techtudo.globo.com#minhas-perguntas.txt
# URL: https://revistagalileu.globo.com/ultimas-noticias/
# Arquivo salvo em: pages/revistagalileu.globo.com#ultimas-noticias#.txt
# URL: https://revistacasaejardim.globo.com/Um-So-Planeta/
# Arquivo salvo em: pages/revistacasaejardim.globo.com#Um-So-Planeta#.txt
# URL: https://revistacrescer.globo.com/gravidez/parto/noticia/2023/03/marido-luta-contra-mortalidade-materna-negra-apos-perder-esposa-no-pos-parto-nao-era-ouvida.ghtml
# URL: https://revistapegn.globo.com/
# Arquivo salvo em: pages/revistacrescer.globo.com#gravidez#parto#noticia#2023#03#marido-luta-contra-mortalidade-materna-negra-apos-perder-esposa-no-pos-parto-nao-era-ouvida.ghtml.txt
# Arquivo salvo em: pages/revistapegn.globo.com#.txt
# URL: http://revistacrescer.globo.com/
# Arquivo salvo em: pages/revistacrescer.globo.com#.txt
# URL: http://revistamonet.globo.com/
# Arquivo salvo em: pages/revistamonet.globo.com#.txt
# URL: https://vidadebicho.globo.com/
# Arquivo salvo em: pages/vidadebicho.globo.com#.txt
# URL: http://vogue.globo.com/
# Arquivo salvo em: pages/vogue.globo.com#.txt
# URL: http://www.globo.com/Globo.com/sites/0,,5623,00.html
# Arquivo salvo em: pages/www.globo.com#Globo.com#sites#0,,5623,00.html.txt
# URL: https://www.uai.com.br/entretenimento/famosos/
# Arquivo salvo em: pages/www.uai.com.br#entretenimento#famosos#.txt
# URL: http://www.globo.com
# Arquivo salvo em: pages/www.globo.com.txt
# URL: https://www.uol.com.br/play/splash/podcast/splash-ve-tv/
# Arquivo salvo em: pages/www.uol.com.br#play#splash#podcast#splash-ve-tv#.txt
# Error: HTTPSConnectionPool(host='privacidade.globo.com', port=443): Max retries exceeded with url: /privacy-policy (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:992)')))
# URL: https://www.uol.com.br/carros/
# Arquivo salvo em: pages/www.uol.com.br#carros#.txt
# URL: https://www.uol.com.br/universa/podcast/sexoterapia/
# Arquivo salvo em: pages/www.uol.com.br#universa#podcast#sexoterapia#.txt
# URL: https://www.uai.com.br/entretenimento/series-e-tv/
# Arquivo salvo em: pages/www.uai.com.br#entretenimento#series-e-tv#.txt
# URL: https://www.bbc.com/news
# Arquivo salvo em: pages/www.bbc.com#news.txt
# URL: https://www.em.com.br/gerais/
# Arquivo salvo em: pages/www.em.com.br#gerais#.txt
# URL: https://www.olhardigital.com.br/editorias/videos/
# Arquivo salvo em: pages/www.olhardigital.com.br#editorias#videos#.txt
# Error: OrderedDict mutated during iteration
# URL: https://www.terra.com.br/diversao/entre-telas/oscar/2023/
# Arquivo salvo em: pages/www.terra.com.br#diversao#entre-telas#oscar#2023#.txt
# URL: https://www.terra.com.br/ao-vivo/diversao/entre-telas/oscar/2023/oscar-2023-saiba-tudo-sobre-vencedores-e-destaques,427b961bfbc511994bb7c9f6af1a6b55uzcc3fh2.html
# Arquivo salvo em: pages/www.terra.com.br#ao-vivo#diversao#entre-telas#oscar#2023#oscar-2023-saiba-tudo-sobre-vencedores-e-destaques,427b961bfbc511994bb7c9f6af1a6b55uzcc3fh2.html.txt
# URL: https://g1.globo.com/especiais/guia-de-compras/?utm_source=globo.com&utm_medium=menu
# Arquivo salvo em: pages/g1.globo.com#especiais#guia-de-compras##utm_source=globo.com#utm_medium=menu.txt
# URL: https://oglobo.globo.com/?utm_source=globo.com&utm_medium=header&utm_campaign=chamada_header
# Arquivo salvo em: pages/oglobo.globo.com##utm_source=globo.com#utm_medium=header#utm_campaign=chamada_header.txt
# URL: https://valor.globo.com/?utm_source=globo.com&utm_medium=header
# Arquivo salvo em: pages/valor.globo.com##utm_source=globo.com#utm_medium=header.txt
# URL: https://www.gazetadopovo.com.br/#explore
# Arquivo salvo em: pages/www.gazetadopovo.com.br##explore.txt
# URL: https://ge.globo.com/futebol/times/corinthians/noticia/2023/03/13/corinthians-corre-risco-de-nao-jogar-a-copa-do-brasil-2024-veja-os-cenarios.ghtml
# Arquivo salvo em: pages/ge.globo.com#futebol#times#corinthians#noticia#2023#03#13#corinthians-corre-risco-de-nao-jogar-a-copa-do-brasil-2024-veja-os-cenarios.ghtml.txt
# URL: https://vitrine.globo.com/?origemId=2528&utm_source=globo.com&utm_medium=header&utm_campaign=vitrine
# Arquivo salvo em: pages/vitrine.globo.com##origemId=2528#utm_source=globo.com#utm_medium=header#utm_campaign=vitrine.txt
# URL: https://globoesporte.globo.com/futebol/times/corinthians/
# Arquivo salvo em: pages/globoesporte.globo.com#futebol#times#corinthians#.txt
# Error: OrderedDict mutated during iteration
# URL: https://gshow.globo.com/novelas/quanto-mais-vida-melhor/
# Arquivo salvo em: pages/gshow.globo.com#novelas#quanto-mais-vida-melhor#.txt
# URL: https://receitas.globo.com/
# Arquivo salvo em: pages/receitas.globo.com#.txt
# URL: https://revistaquem.globo.com/?utm_source=globo.com&utm_medium=header
# Arquivo salvo em: pages/revistaquem.globo.com##utm_source=globo.com#utm_medium=header.txt
# URL: http://www.cnpq.br/#portal-footer
# Arquivo salvo em: pages/www.cnpq.br##portal-footer.txt
# URL: http://www.cnpq.br/pt-br/termos-de-uso
# URL: http://www.cnpq.br/planalto
# Arquivo salvo em: pages/www.cnpq.br#pt-br#termos-de-uso.txt
# Arquivo salvo em: pages/www.cnpq.br#planalto.txt
# URL: http://especiais.g1.globo.com/educacao/guia-de-carreiras/2017/teste-vocacional/
# Arquivo salvo em: pages/especiais.g1.globo.com#educacao#guia-de-carreiras#2017#teste-vocacional#.txt
# URL: http://app.globoesporte.globo.com/futebol/publico-no-brasil/time/corinthians/
# Arquivo salvo em: pages/app.globoesporte.globo.com#futebol#publico-no-brasil#time#corinthians#.txt
# URL: https://globoplay.globo.com/canais/canal-brasil/
# Arquivo salvo em: pages/globoplay.globo.com#canais#canal-brasil#.txt
# URL: https://interativos.globoesporte.globo.com/tabelas/
# Arquivo salvo em: pages/interativos.globoesporte.globo.com#tabelas#.txt
# URL: https://www.estadao.com.br/politica
# Arquivo salvo em: pages/www.estadao.com.br#politica.txt
# Error: OrderedDict mutated during iteration
# URL: https://valorinveste.globo.com/?utm_source=globocom&utm_medium=referral&utm_campaign=menulateral-globocom
# Arquivo salvo em: pages/valorinveste.globo.com##utm_source=globocom#utm_medium=referral#utm_campaign=menulateral-globocom.txt
# URL: https://autoesporte.globo.com/carros/
# Arquivo salvo em: pages/autoesporte.globo.com#carros#.txt
# URL: https://extra.globo.com/famosos/conheca-condominio-onde-michelle-mora-de-aluguel-com-as-filhas-desde-ida-de-bolsonaro-para-os-eua-25674201.html
# Arquivo salvo em: pages/extra.globo.com#famosos#conheca-condominio-onde-michelle-mora-de-aluguel-com-as-filhas-desde-ida-de-bolsonaro-para-os-eua-25674201.html.txt
# URL: https://epocanegocios.globo.com/futuro-do-dinheiro/
# Arquivo salvo em: pages/epocanegocios.globo.com#futuro-do-dinheiro#.txt
# URL: https://www.techtudo.com.br/informatica/notebooks/
# Arquivo salvo em: pages/www.techtudo.com.br#informatica#notebooks#.txt
# URL: https://globorural.globo.com/tempo/
# Arquivo salvo em: pages/globorural.globo.com#tempo#.txt
# URL: https://radioglobo.globo.com/programacao/PROGRAMACAO.htm
# Arquivo salvo em: pages/radioglobo.globo.com#programacao#PROGRAMACAO.htm.txt
# URL: https://bhfm.globo.com/programacao/PROGRAMACAO.htm
# Arquivo salvo em: pages/bhfm.globo.com#programacao#PROGRAMACAO.htm.txt
# URL: https://umsoplaneta.globo.com/sociedade/noticia/2021/06/07/um-so-planeta-quem-somos.ghtml
# Arquivo salvo em: pages/umsoplaneta.globo.com#sociedade#noticia#2021#06#07#um-so-planeta-quem-somos.ghtml.txt
# URL: https://revistaglamour.globo.com/um-so-planeta/
# Arquivo salvo em: pages/revistaglamour.globo.com#um-so-planeta#.txt
# URL: https://casavogue.globo.com/interiores/apartamentos/
# Arquivo salvo em: pages/casavogue.globo.com#interiores#apartamentos#.txt
# URL: https://gq.globo.com/um-so-planeta/
# Arquivo salvo em: pages/gq.globo.com#um-so-planeta#.txt
# URL: https://revistamonet.globo.com/premiacao/noticia/2023/03/cantora-abala-evento-pos-oscar-com-vestido-transparente-e-calcinha-fio-dental.ghtml
# Arquivo salvo em: pages/revistamonet.globo.com#premiacao#noticia#2023#03#cantora-abala-evento-pos-oscar-com-vestido-transparente-e-calcinha-fio-dental.ghtml.txt
# URL: https://vogue.globo.com/um-so-planeta/noticia/2023/03/os-looks-sustentaveis-que-cruzaram-o-tapete-vermelho-do-oscar-2023.ghtml
# Arquivo salvo em: pages/vogue.globo.com#um-so-planeta#noticia#2023#03#os-looks-sustentaveis-que-cruzaram-o-tapete-vermelho-do-oscar-2023.ghtml.txt
# Error: OrderedDict mutated during iteration
# URL: https://forum.techtudo.globo.com/minhas-respostas
# Arquivo salvo em: pages/forum.techtudo.globo.com#minhas-respostas.txt
# URL: https://vidadebicho.globo.com/adestramento/
# Arquivo salvo em: pages/vidadebicho.globo.com#adestramento#.txt
# URL: http://revistamarieclaire.globo.com/
# Arquivo salvo em: pages/revistamarieclaire.globo.com#.txt
# URL: http://fantastico.globo.com/
# Arquivo salvo em: pages/fantastico.globo.com#.txt
# URL: https://revistagalileu.globo.com/ciencia/
# Arquivo salvo em: pages/revistagalileu.globo.com#ciencia#.txt
# URL: https://revistacasaejardim.globo.com/arquitetura/projetos-comerciais/
# Arquivo salvo em: pages/revistacasaejardim.globo.com#arquitetura#projetos-comerciais#.txt
# URL: https://revistacrescer.globo.com/Um-So-Planeta
# Arquivo salvo em: pages/revistacrescer.globo.com#Um-So-Planeta.txt
# URL: https://revistapegn.globo.com/Um-So-Planeta
# Arquivo salvo em: pages/revistapegn.globo.com#Um-So-Planeta.txt
# URL: https://revistamarieclaire.globo.com/saude/noticia/2023/03/parto-humanizado-precisa-de-doula-pode-tomar-remedios-tire-duvidas.ghtml
# Arquivo salvo em: pages/revistamarieclaire.globo.com#saude#noticia#2023#03#parto-humanizado-precisa-de-doula-pode-tomar-remedios-tire-duvidas.ghtml.txt
# URL: http://mundogloob.globo.com/
# Arquivo salvo em: pages/mundogloob.globo.com#.txt
# URL: https://redeglobo.globo.com/
# Arquivo salvo em: pages/redeglobo.globo.com#.txt
# URL: https://www.bbc.com/sport
# Arquivo salvo em: pages/www.bbc.com#sport.txt
# URL: https://www.uol.com.br/carros/avaliacao/
# Arquivo salvo em: pages/www.uol.com.br#carros#avaliacao#.txt
# URL: http://www.globo.com/campanhasdevideo
# URL: https://www.uai.com.br/entretenimento/series-e-tv/realities/
# Arquivo salvo em: pages/www.globo.com#campanhasdevideo.txt
# Arquivo salvo em: pages/www.uai.com.br#entretenimento#series-e-tv#realities#.txt
# URL: http://www.globo.com/todos-os-sites.html
# Arquivo salvo em: pages/www.globo.com#todos-os-sites.html.txt
# URL: https://www.olhardigital.com.br/web-stories/
# Arquivo salvo em: pages/www.olhardigital.com.br#web-stories#.txt
# URL: https://www.uol.com.br/carros/mobilidade/
# Arquivo salvo em: pages/www.uol.com.br#carros#mobilidade#.txt
# URL: https://www.uai.com.br/entretenimento/cinema/
# Arquivo salvo em: pages/www.uai.com.br#entretenimento#cinema#.txt
# URL: http://www.cnpq.br/governodigital/pt-br/dados-abertos
# Arquivo salvo em: pages/www.cnpq.br#governodigital#pt-br#dados-abertos.txt
# URL: https://www.olhardigital.com.br/editorias/ciencia-e-espaco/
# Arquivo salvo em: pages/www.olhardigital.com.br#editorias#ciencia-e-espaco#.txt
# URL: http://www.cnpq.br/economia/pt-br/acesso-a-informacao/servidores/servidores-publicos/painel-estatistico-de-pessoal
# URL: https://www.em.com.br/politica/
# Arquivo salvo em: pages/www.cnpq.br#economia#pt-br#acesso-a-informacao#servidores#servidores-publicos#painel-estatistico-de-pessoal.txt
# Arquivo salvo em: pages/www.em.com.br#politica#.txt
# URL: https://www.bbc.com/reel
# Arquivo salvo em: pages/www.bbc.com#reel.txt
# URL: https://www.estadao.com.br/economia
# Arquivo salvo em: pages/www.estadao.com.br#economia.txt
# URL: https://www.estadao.com.br/politica/eleicoes/
# Arquivo salvo em: pages/www.estadao.com.br#politica#eleicoes#.txt
# URL: https://oglobo.globo.com/esportes/noticia/2023/03/por-que-o-vasco-de-barbieri-parece-correr-mais-do-que-o-flamengo-de-vitor-pereira.ghtml?utm_source=globo.com&utm_medium=oglobo
# Arquivo salvo em: pages/oglobo.globo.com#esportes#noticia#2023#03#por-que-o-vasco-de-barbieri-parece-correr-mais-do-que-o-flamengo-de-vitor-pereira.ghtml#utm_source=globo.com#utm_medium=oglobo.txt
# URL: https://www.terra.com.br/diversao/
# Arquivo salvo em: pages/www.terra.com.br#diversao#.txt
# URL: https://valor.globo.com/valor-data/?utm_source=globo.com&utm_medium=widget&utm_campaign=economia
# Arquivo salvo em: pages/valor.globo.com#valor-data##utm_source=globo.com#utm_medium=widget#utm_campaign=economia.txt
# URL: https://g1.globo.com/educacao/enem/2020/
# Arquivo salvo em: pages/g1.globo.com#educacao#enem#2020#.txt
# URL: https://vitrine.globo.com/?origemId=2528&utm_source=globo.com&utm_medium=header&utm_campaign=vitrine-tooltip
# Arquivo salvo em: pages/vitrine.globo.com##origemId=2528#utm_source=globo.com#utm_medium=header#utm_campaign=vitrine-tooltip.txt
# URL: https://www.terra.com.br/especiais/verao/
# Arquivo salvo em: pages/www.terra.com.br#especiais#verao#.txt
# URL: https://www.gazetadopovo.com.br/saiba-agora/?ref=explore
# Arquivo salvo em: pages/www.gazetadopovo.com.br#saiba-agora##ref=explore.txt
# URL: https://globoesporte.globo.com/rs/futebol/times/gremio/
# Arquivo salvo em: pages/globoesporte.globo.com#rs#futebol#times#gremio#.txt
# URL: https://ge.globo.com/futebol/times/flamengo/noticia/2023/03/13/vitor-pereira-nao-repetiu-escalacao-no-flamengo-veja-balanco-apos-15-jogos.ghtml
# Arquivo salvo em: pages/ge.globo.com#futebol#times#flamengo#noticia#2023#03#13#vitor-pereira-nao-repetiu-escalacao-no-flamengo-veja-balanco-apos-15-jogos.ghtml.txt
# URL: https://revistaquem.globo.com/ultimas-noticias/
# Arquivo salvo em: pages/revistaquem.globo.com#ultimas-noticias#.txt
# URL: https://gshow.globo.com/novelas/um-lugar-ao-sol/
# Arquivo salvo em: pages/gshow.globo.com#novelas#um-lugar-ao-sol#.txt
# URL: https://receitas.globo.com/tipos-de-prato/doces-e-sobremesas/
# Arquivo salvo em: pages/receitas.globo.com#tipos-de-prato#doces-e-sobremesas#.txt
# URL: http://app.globoesporte.globo.com/futebol/publico-no-brasil/time/sao-paulo/
# Arquivo salvo em: pages/app.globoesporte.globo.com#futebol#publico-no-brasil#time#sao-paulo#.txt
# URL: http://especiais.g1.globo.com/rio-de-janeiro/2018/fora-do-ponto-linhas-de-onibus/
# Arquivo salvo em: pages/especiais.g1.globo.com#rio-de-janeiro#2018#fora-do-ponto-linhas-de-onibus#.txt
# URL: https://interativos.globoesporte.globo.com/estatisticas/
# Arquivo salvo em: pages/interativos.globoesporte.globo.com#estatisticas#.txt
# URL: https://globoplay.globo.com/canais/canal-off/
# Arquivo salvo em: pages/globoplay.globo.com#canais#canal-off#.txt
# URL: https://valorinveste.globo.com/
# Arquivo salvo em: pages/valorinveste.globo.com#.txt
# URL: https://www.techtudo.com.br/jogos/
# Arquivo salvo em: pages/www.techtudo.com.br#jogos#.txt
# URL: https://autoesporte.globo.com/carros/carro-do-ano/
# Arquivo salvo em: pages/autoesporte.globo.com#carros#carro-do-ano#.txt
# URL: http://extra.globo.com/
# Arquivo salvo em: pages/extra.globo.com#.txt
# URL: https://epocanegocios.globo.com/futuro-do-trabalho/
# Arquivo salvo em: pages/epocanegocios.globo.com#futuro-do-trabalho#.txt
# URL: https://globorural.globo.com/especiais/fazenda-sustentavel/
# Arquivo salvo em: pages/globorural.globo.com#especiais#fazenda-sustentavel#.txt
# URL: https://radioglobo.globo.com/promocoes/PROMOCOES.htm
# Arquivo salvo em: pages/radioglobo.globo.com#promocoes#PROMOCOES.htm.txt
# URL: https://casavogue.globo.com/interiores/casas/
# Arquivo salvo em: pages/casavogue.globo.com#interiores#casas#.txt
# URL: https://bhfm.globo.com/promocoes/PROMOCOES.htm
# Arquivo salvo em: pages/bhfm.globo.com#promocoes#PROMOCOES.htm.txt
# URL: http://revistaglamour.globo.com/principios-editoriais-do-grupo-globo/
# Arquivo salvo em: pages/revistaglamour.globo.com#principios-editoriais-do-grupo-globo#.txt
# URL: http://umsoplaneta.globo.com/clima
# Arquivo salvo em: pages/umsoplaneta.globo.com#clima.txt
# URL: https://gq.globo.com/
# Arquivo salvo em: pages/gq.globo.com#.txt
# URL: https://revistamonet.globo.com/
# Arquivo salvo em: pages/revistamonet.globo.com#.txt
# URL: https://vogue.globo.com/um-so-planeta/
# Arquivo salvo em: pages/vogue.globo.com#um-so-planeta#.txt
# Error: OrderedDict mutated during iteration
# URL: https://forum.techtudo.globo.com/trofeus
# Arquivo salvo em: pages/forum.techtudo.globo.com#trofeus.txt
# URL: https://vidadebicho.globo.com/colunistas/
# Arquivo salvo em: pages/vidadebicho.globo.com#colunistas#.txt
# URL: https://gnt.globo.com/
# Arquivo salvo em: pages/gnt.globo.com#.txt
# URL: https://revistagalileu.globo.com/saude/
# Arquivo salvo em: pages/revistagalileu.globo.com#saude#.txt
# URL: https://revistacasaejardim.globo.com/arquitetura/
# Arquivo salvo em: pages/revistacasaejardim.globo.com#arquitetura#.txt
# URL: https://revistapegn.globo.com/ultimas-noticias/
# Arquivo salvo em: pages/revistapegn.globo.com#ultimas-noticias#.txt
# URL: https://revistacrescer.globo.com/
# Arquivo salvo em: pages/revistacrescer.globo.com#.txt
# URL: https://revistamarieclaire.globo.com/
# Arquivo salvo em: pages/revistamarieclaire.globo.com#.txt
# URL: https://redeglobo.globo.com/globominas/
# Arquivo salvo em: pages/redeglobo.globo.com#globominas#.txt
# URL: http://gnt.globo.com/
# Arquivo salvo em: pages/gnt.globo.com#.txt
# URL: https://www.uol.com.br/carros/motos/
# Arquivo salvo em: pages/www.uol.com.br#carros#motos#.txt
# URL: https://www.bbc.com/worklife
# Arquivo salvo em: pages/www.bbc.com#worklife.txt
# URL: https://www.telecineplay.com.br/
# Arquivo salvo em: pages/www.telecineplay.com.br#.txt
# URL: https://www.olhardigital.com.br/editorias/carros-e-tecnologia/
# Arquivo salvo em: pages/www.olhardigital.com.br#editorias#carros-e-tecnologia#.txt
# URL: http://www.cnpq.br/acessoainformacao/pt-br
# Arquivo salvo em: pages/www.cnpq.br#acessoainformacao#pt-br.txt
# URL: https://www.uai.com.br/entretenimento/musica/
# Arquivo salvo em: pages/www.uai.com.br#entretenimento#musica#.txt
# URL: https://www.em.com.br/economia/
# Arquivo salvo em: pages/www.em.com.br#economia#.txt
# URL: https://g1.globo.com/loterias/
# Arquivo salvo em: pages/g1.globo.com#loterias#.txt
# URL: http://oglobo.globo.com/
# Arquivo salvo em: pages/oglobo.globo.com#.txt
# URL: https://valor.globo.com/
# URL: https://ge.globo.com/futebol/times/fluminense/noticia/2023/03/13/lele-diz-que-foi-dificil-enfrentar-e-fazer-gol-no-fluminense-seu-futuro-clube-tem-que-estar-bem-focado.ghtml
# Arquivo salvo em: pages/valor.globo.com#.txt
# URL: https://www.terra.com.br/diversao/tv/reality-shows/
# Arquivo salvo em: pages/ge.globo.com#futebol#times#fluminense#noticia#2023#03#13#lele-diz-que-foi-dificil-enfrentar-e-fazer-gol-no-fluminense-seu-futuro-clube-tem-que-estar-bem-focado.ghtml.txt
# Arquivo salvo em: pages/www.terra.com.br#diversao#tv#reality-shows#.txt
# URL: https://www.gazetadopovo.com.br/ultimas-noticias/?ref=explore
# Arquivo salvo em: pages/www.gazetadopovo.com.br#ultimas-noticias##ref=explore.txt
# URL: https://vitrine.globo.com/bbb22?origemId=2540&utm_source=gcom&utm_medium=votacao-assine&utm_campaign=1-Reali-BBB22&utm_term=box-votacao-home&utm_content=aq-organica
# Arquivo salvo em: pages/vitrine.globo.com#bbb22#origemId=2540#utm_source=gcom#utm_medium=votacao-assine#utm_campaign=1-Reali-BBB22#utm_term=box-votacao-home#utm_content=aq-organica.txt
# URL: https://www.globo.com/Portal/anuncie/glb_anuncie_panfleto
# Arquivo salvo em: pages/www.globo.com#Portal#anuncie#glb_anuncie_panfleto.txt
# URL: https://globoesporte.globo.com/futebol/times/palmeiras/
# Arquivo salvo em: pages/globoesporte.globo.com#futebol#times#palmeiras#.txt
# URL: https://gshow.globo.com/realities/the-voice-mais/
# Arquivo salvo em: pages/gshow.globo.com#realities#the-voice-mais#.txt
# URL: https://www.estadao.com.br/economia/agronegocios
# URL: https://revistaquem.globo.com/noticias/
# Arquivo salvo em: pages/www.estadao.com.br#economia#agronegocios.txt
# Arquivo salvo em: pages/revistaquem.globo.com#noticias#.txt
# URL: http://app.globoesporte.globo.com/futebol/publico-no-brasil/time/internacional/
# Arquivo salvo em: pages/app.globoesporte.globo.com#futebol#publico-no-brasil#time#internacional#.txt
# URL: https://receitas.globo.com/tipos-de-prato/tortas-e-bolos/
# Arquivo salvo em: pages/receitas.globo.com#tipos-de-prato#tortas-e-bolos#.txt
# URL: http://especiais.g1.globo.com/economia/agronegocios/globo-rural/guia-do-globo-rural/
# Arquivo salvo em: pages/especiais.g1.globo.com#economia#agronegocios#globo-rural#guia-do-globo-rural#.txt
# URL: https://interativos.globoesporte.globo.com/podcasts/programa/ponte-aerea/
# Arquivo salvo em: pages/interativos.globoesporte.globo.com#podcasts#programa#ponte-aerea#.txt
# URL: https://www.techtudo.com.br/e-sports/
# Arquivo salvo em: pages/www.techtudo.com.br#e-sports#.txt
# URL: https://extra.globo.com/fotografias/
# URL: https://valorinveste.globo.com/?utm_source=valor&utm_medium=referral&utm_campaign=menulateral-valor
# Arquivo salvo em: pages/extra.globo.com#fotografias#.txt
# Arquivo salvo em: pages/valorinveste.globo.com##utm_source=valor#utm_medium=referral#utm_campaign=menulateral-valor.txt
# URL: https://forum.techtudo.globo.com/pergunte
# Arquivo salvo em: pages/forum.techtudo.globo.com#pergunte.txt
# URL: https://globorural.globo.com/agricultura/
# Arquivo salvo em: pages/globorural.globo.com#agricultura#.txt
# URL: https://epocanegocios.globo.com/tecnologia/
# Arquivo salvo em: pages/epocanegocios.globo.com#tecnologia#.txt
# URL: https://autoesporte.globo.com/carros/boletim-cbn/
# Arquivo salvo em: pages/autoesporte.globo.com#carros#boletim-cbn#.txt
# URL: https://globoplay.globo.com/canais/futura/
# Arquivo salvo em: pages/globoplay.globo.com#canais#futura#.txt
# URL: https://radioglobo.globo.com/eventos/EVENTOS.htm
# Arquivo salvo em: pages/radioglobo.globo.com#eventos#EVENTOS.htm.txt
# URL: https://bhfm.globo.com/eventos/EVENTOS.htm
# Arquivo salvo em: pages/bhfm.globo.com#eventos#EVENTOS.htm.txt
# URL: https://casavogue.globo.com/interiores/casas-de-famosos/
# Arquivo salvo em: pages/casavogue.globo.com#interiores#casas-de-famosos#.txt
# URL: https://gq.globo.com/lifestyle/gastronomia/
# Arquivo salvo em: pages/gq.globo.com#lifestyle#gastronomia#.txt
# URL: http://revistaglamour.globo.com/termos-de-uso
# Arquivo salvo em: pages/revistaglamour.globo.com#termos-de-uso.txt
# URL: https://revistamonet.globo.com/noticias/
# Arquivo salvo em: pages/revistamonet.globo.com#noticias#.txt
# URL: http://umsoplaneta.globo.com/energia
# Arquivo salvo em: pages/umsoplaneta.globo.com#energia.txt
# URL: https://vogue.globo.com/
# Arquivo salvo em: pages/vogue.globo.com#.txt
# Error: OrderedDict mutated during iteration
# URL: https://vidadebicho.globo.com/colunistas/belmiro-pelo-mundo/
# Arquivo salvo em: pages/vidadebicho.globo.com#colunistas#belmiro-pelo-mundo#.txt
# URL: https://www.telecineplay.com.br/#quem-somos
# Arquivo salvo em: pages/www.telecineplay.com.br##quem-somos.txt
# URL: http://somos.globo.com
# Arquivo salvo em: pages/somos.globo.com.txt
# URL: https://memoriaglobo.globo.com/
# Arquivo salvo em: pages/memoriaglobo.globo.com#.txt
# URL: https://historia.globo.com/
# Arquivo salvo em: pages/historia.globo.com# .txt
# URL: http://grupoglobo.globo.com/
# Arquivo salvo em: pages/grupoglobo.globo.com#.txt
# URL: https://glamour.globo.com/moda/noticia/2023/03/gravida-do-segundo-filho-rihanna-mostra-a-barriguinha-em-backstage-do-oscar.ghtml
# Arquivo salvo em: pages/glamour.globo.com#moda#noticia#2023#03#gravida-do-segundo-filho-rihanna-mostra-a-barriguinha-em-backstage-do-oscar.ghtml.txt
# URL: https://www.climatempo.com.br/
# Arquivo salvo em: pages/www.climatempo.com.br#.txt
# URL: https://estuda.com/
# Arquivo salvo em: pages/estuda.com#.txt
# URL: http://globofilmes.globo.com/
# Arquivo salvo em: pages/globofilmes.globo.com#.txt
# URL: http://revistaautoesporte.globo.com/
# Arquivo salvo em: pages/revistaautoesporte.globo.com#.txt
# URL: https://www.publicidadeeditoraglobo.com.br/
# Arquivo salvo em: pages/www.publicidadeeditoraglobo.com.br#.txt
# URL: https://multishow.globo.com/
# Arquivo salvo em: pages/multishow.globo.com#.txt
# URL: https://revistagalileu.globo.com/saude/vacina-e-saude/
# Arquivo salvo em: pages/revistagalileu.globo.com#saude#vacina-e-saude#.txt
# URL: https://revistapegn.globo.com/franquias/
# Arquivo salvo em: pages/revistapegn.globo.com#franquias#.txt
# URL: https://revistacasaejardim.globo.com/comportamento/bem-estar-e-saude/
# Arquivo salvo em: pages/revistacasaejardim.globo.com#comportamento#bem-estar-e-saude#.txt
# URL: https://revistacrescer.globo.com/tentantes/infertilidade/
# Arquivo salvo em: pages/revistacrescer.globo.com#tentantes#infertilidade#.txt
# URL: https://revistamarieclaire.globo.com/moda/noivas/
# Arquivo salvo em: pages/revistamarieclaire.globo.com#moda#noivas#.txt
# URL: https://redeglobo.globo.com/Responsabilidade-Social/educacao/
# Arquivo salvo em: pages/redeglobo.globo.com#Responsabilidade-Social#educacao#.txt
# URL: http://multishow.globo.com/
# Arquivo salvo em: pages/multishow.globo.com#.txt
# URL: https://www.uol.com.br/carros/lancamentos-e-mercado/
# Arquivo salvo em: pages/www.uol.com.br#carros#lancamentos-e-mercado#.txt
# URL: https://www.globo.com/campanhasdevideo
# Arquivo salvo em: pages/www.globo.com#campanhasdevideo.txt
# URL: https://www.bbc.com/travel
# Arquivo salvo em: pages/www.bbc.com#travel.txt
# URL: https://www.uai.com.br/entretenimento/musica/sertaneja/
# Arquivo salvo em: pages/www.uai.com.br#entretenimento#musica#sertaneja#.txt
# URL: https://www.olhardigital.com.br/editorias/seguranca/
# Arquivo salvo em: pages/www.olhardigital.com.br#editorias#seguranca#.txt
# URL: http://www.valor.com.br/
# Arquivo salvo em: pages/www.valor.com.br#.txt
# URL: http://www.cnpq.br/pt-br/termos-de-uso#wrapper
# Arquivo salvo em: pages/www.cnpq.br#pt-br#termos-de-uso#wrapper.txt
# URL: https://www.em.com.br/nacional/
# Arquivo salvo em: pages/www.em.com.br#nacional#.txt
# URL: https://oglobo.globo.com/ultimas-noticias/
# URL: https://www.estadao.com.br/economia/governanca
# Arquivo salvo em: pages/oglobo.globo.com#ultimas-noticias#.txt
# Arquivo salvo em: pages/www.estadao.com.br#economia#governanca.txt
# URL: http://g1.globo.com/hora1
# Arquivo salvo em: pages/g1.globo.com#hora1.txt
# URL: https://valor.globo.com/valor-data/
# Arquivo salvo em: pages/valor.globo.com#valor-data#.txt
# URL: https://ge.globo.com/surfe/ao-vivo/wsl-2023-etapa-de-peniche.ghtml
# Arquivo salvo em: pages/ge.globo.com#surfe#ao-vivo#wsl-2023-etapa-de-peniche.ghtml.txt
# URL: https://www.gazetadopovo.com.br/opiniao/bom-dia/?ref=explore
# Arquivo salvo em: pages/www.gazetadopovo.com.br#opiniao#bom-dia##ref=explore.txt
# URL: https://vitrine.globo.com/?origemId=2803&utm_source=gcom&utm_medium=home-franja-vitrine&utm_campaign=botao-assine
# Arquivo salvo em: pages/vitrine.globo.com##origemId=2803#utm_source=gcom#utm_medium=home-franja-vitrine#utm_campaign=botao-assine.txt
# URL: https://globoesporte.globo.com/sp/santos-e-regiao/futebol/times/santos/
# Arquivo salvo em: pages/globoesporte.globo.com#sp#santos-e-regiao#futebol#times#santos#.txt
# URL: https://revistaquem.globo.com/entretenimento/tv-e-novelas/bbb/
# Arquivo salvo em: pages/revistaquem.globo.com#entretenimento#tv-e-novelas#bbb#.txt
# URL: https://gshow.globo.com/realities/the-masked-singer-brasil/
# Arquivo salvo em: pages/gshow.globo.com#realities#the-masked-singer-brasil#.txt
# URL: https://receitas.globo.com/tipos-de-prato/massas/
# Arquivo salvo em: pages/receitas.globo.com#tipos-de-prato#massas#.txt
# URL: https://globoplay.globo.com/canais/gloobinho/
# URL: https://www.terra.com.br/esportes/
# Arquivo salvo em: pages/globoplay.globo.com#canais#gloobinho#.txt
# Arquivo salvo em: pages/www.terra.com.br#esportes#.txt
# URL: http://app.globoesporte.globo.com/futebol/publico-no-brasil/time/palmeiras/
# Arquivo salvo em: pages/app.globoesporte.globo.com#futebol#publico-no-brasil#time#palmeiras#.txt
# URL: http://especiais.g1.globo.com/globonews/2017/acompanhe-o-time-da-globonews-no-twitter/
# Arquivo salvo em: pages/especiais.g1.globo.com#globonews#2017#acompanhe-o-time-da-globonews-no-twitter#.txt
# URL: https://interativos.globoesporte.globo.com/esports/lol/tabela-cblol/2022
# URL: https://valorinveste.globo.com/?utm_source=valor&utm_medium=referral&utm_campaign=menu-valor
# URL: https://extra.globo.com/promocao/
# Arquivo salvo em: pages/interativos.globoesporte.globo.com#esports#lol#tabela-cblol#2022.txt
# Arquivo salvo em: pages/valorinveste.globo.com##utm_source=valor#utm_medium=referral#utm_campaign=menu-valor.txt
# Arquivo salvo em: pages/extra.globo.com#promocao#.txt
# URL: https://autoesporte.globo.com/carros/podcast/
# Arquivo salvo em: pages/autoesporte.globo.com#carros#podcast#.txt
# URL: https://www.techtudo.com.br/softwares/apps/
# Arquivo salvo em: pages/www.techtudo.com.br#softwares#apps#.txt
# URL: https://globorural.globo.com/agricultura/algodao/
# Arquivo salvo em: pages/globorural.globo.com#agricultura#algodao#.txt
# URL: https://epocanegocios.globo.com/sustentabilidade/
# Arquivo salvo em: pages/epocanegocios.globo.com#sustentabilidade#.txt
# URL: https://radioglobo.globo.com/texto/2023/03/08/EU-SEMPRE-VOU-SER-BARRAQUEIRA-ARROGANTE-E-SEM-HUMILDADE-PORQUE-EU-SOU-UMA-MULHER-PRETA.htm
# Arquivo salvo em: pages/radioglobo.globo.com#texto#2023#03#08#EU-SEMPRE-VOU-SER-BARRAQUEIRA-ARROGANTE-E-SEM-HUMILDADE-PORQUE-EU-SOU-UMA-MULHER-PRETA.htm.txt
# URL: https://bhfm.globo.com/fale-conosco/FALE-CONOSCO.htm
# Arquivo salvo em: pages/bhfm.globo.com#fale-conosco#FALE-CONOSCO.htm.txt
# URL: https://umsoplaneta.globo.com/financas/
# Arquivo salvo em: pages/umsoplaneta.globo.com#financas#.txt
# URL: https://revistaglamour.globo.com/principios-editoriais-do-grupo-globo/
# Arquivo salvo em: pages/revistaglamour.globo.com#principios-editoriais-do-grupo-globo#.txt
# URL: https://casavogue.globo.com/interiores/home-office/
# Arquivo salvo em: pages/casavogue.globo.com#interiores#home-office#.txt
# URL: https://gq.globo.com/lifestyle/bebidas/
# Arquivo salvo em: pages/gq.globo.com#lifestyle#bebidas#.txt
# URL: https://revistamonet.globo.com/celebridades/
# Arquivo salvo em: pages/revistamonet.globo.com#celebridades#.txt
# URL: https://vogue.globo.com/moda/news/
# Arquivo salvo em: pages/vogue.globo.com#moda#news#.txt
# Error: OrderedDict mutated during iteration
# URL: https://vidadebicho.globo.com/colunistas/biologia-aplicada/
# Arquivo salvo em: pages/vidadebicho.globo.com#colunistas#biologia-aplicada#.txt
# Error: OrderedDict mutated during iteration
# URL: https://memoriaglobo.globo.com/jornalismo/jornalismo-e-telejornais/fantastico/
# Arquivo salvo em: pages/memoriaglobo.globo.com#jornalismo#jornalismo-e-telejornais#fantastico#.txt
# URL: https://www.telecineplay.com.br/programacao
# Arquivo salvo em: pages/www.telecineplay.com.br#programacao.txt
# URL: https://forum.techtudo.globo.com/usuarios
# Arquivo salvo em: pages/forum.techtudo.globo.com#usuarios.txt
# URL: https://historia.globo.com/
# Arquivo salvo em: pages/historia.globo.com#.txt
# URL: https://www.climatempo.com.br
# Arquivo salvo em: pages/www.climatempo.com.br.txt
# URL: https://glamour.globo.com/entretenimento/musica/noticia/2023/03/lady-gaga-se-apresenta-no-oscar-2023.ghtml
# Arquivo salvo em: pages/glamour.globo.com#entretenimento#musica#noticia#2023#03#lady-gaga-se-apresenta-no-oscar-2023.ghtml.txt
# URL: https://globofilmes.globo.com/
# Arquivo salvo em: pages/globofilmes.globo.com#.txt
# URL: https://estuda.com/#content
# Arquivo salvo em: pages/estuda.com##content.txt
# Error: OrderedDict mutated during iteration
# URL: https://grupoglobo.globo.com/
# Arquivo salvo em: pages/grupoglobo.globo.com#.txt
# URL: http://www.valor.com.br/revistas/valid.php
# Arquivo salvo em: pages/www.valor.com.br#revistas#valid.php.txt
# URL: https://canaisglobo.globo.com/
# Arquivo salvo em: pages/canaisglobo.globo.com#.txt
# URL: http://www.publicidadeeditoraglobo.com.br/
# Arquivo salvo em: pages/www.publicidadeeditoraglobo.com.br# .txt
# URL: http://combate.globo.com/
# Arquivo salvo em: pages/combate.globo.com#.txt
# URL: https://canaloff.globo.com/
# Arquivo salvo em: pages/canaloff.globo.com#.txt
# URL: https://cbn.globoradio.globo.com/
# Arquivo salvo em: pages/cbn.globoradio.globo.com#.txt
# URL: https://vempraglobo.g.globo/
# Arquivo salvo em: pages/vempraglobo.g.globo#.txt
# URL: https://conta.globo.com/
# Arquivo salvo em: pages/conta.globo.com#.txt
# URL: https://globoventures.globo.com/
# Arquivo salvo em: pages/globoventures.globo.com#.txt
# URL: https://www.alice.com.br/
# Arquivo salvo em: pages/www.alice.com.br#.txt
# URL: https://www.globo.com
# Arquivo salvo em: pages/www.globo.com.txt
# URL: https://arena.im/
# Arquivo salvo em: pages/arena.im#.txt
# URL: https://www.buser.com.br
# Arquivo salvo em: pages/www.buser.com.br.txt
# URL: https://www.emcasa.com
# Arquivo salvo em: pages/www.emcasa.com.txt
# Error: 'content-type'
# URL: https://site.franq.com.br/
# Arquivo salvo em: pages/site.franq.com.br#.txt
# URL: https://galena.com/
# Arquivo salvo em: pages/galena.com#.txt
# URL: http://www.cnpq.br/pt-br/termos-de-uso#main-navigation
# Arquivo salvo em: pages/www.cnpq.br#pt-br#termos-de-uso#main-navigation.txt
# URL: https://www.uol.com.br/carros/segredos-automotivos/
# Arquivo salvo em: pages/www.uol.com.br#carros#segredos-automotivos#.txt
# URL: https://www.gabriel.com.br
# Arquivo salvo em: pages/www.gabriel.com.br.txt
# URL: https://www.uai.com.br/entretenimento/trends/
# Arquivo salvo em: pages/www.uai.com.br#entretenimento#trends#.txt
# URL: https://www.bbc.com/future
# Arquivo salvo em: pages/www.bbc.com#future.txt
# URL: https://www.olhardigital.com.br/editorias/dicas-e-tutoriais/
# Arquivo salvo em: pages/www.olhardigital.com.br#editorias#dicas-e-tutoriais#.txt
# URL: https://www.terra.com.br/vida-e-estilo/horoscopo/
# Arquivo salvo em: pages/www.terra.com.br#vida-e-estilo#horoscopo#.txt
# URL: https://www.estadao.com.br/economia/midia-mkt
# Arquivo salvo em: pages/www.estadao.com.br#economia#midia-mkt.txt
# URL: https://www.hashdex.com.br
# Arquivo salvo em: pages/www.hashdex.com.br.txt
# URL: https://www.idwall.co
# Arquivo salvo em: pages/www.idwall.co.txt
# URL: https://www.ingresse.com
# Arquivo salvo em: pages/www.ingresse.com.txt
# URL: https://www.kovi.com.br
# Arquivo salvo em: pages/www.kovi.com.br.txt
# URL: https://www.em.com.br/internacional/
# Arquivo salvo em: pages/www.em.com.br#internacional#.txt
# URL: http://revistagloborural.globo.com/
# Arquivo salvo em: pages/revistagloborural.globo.com#.txt
# URL: http://g1.globo.com/bom-dia-brasil/
# Arquivo salvo em: pages/g1.globo.com#bom-dia-brasil#.txt
# URL: https://www.gazetadopovo.com.br/newsletter/?ref=explore
# Arquivo salvo em: pages/www.gazetadopovo.com.br#newsletter##ref=explore.txt
# URL: https://oglobo.globo.com/politica/
# Arquivo salvo em: pages/oglobo.globo.com#politica#.txt
# URL: https://valor.globo.com/valor-data/bolsas/
# Arquivo salvo em: pages/valor.globo.com#valor-data#bolsas#.txt
# URL: https://vitrine.globo.com/assine/bbb?origemId=91139&utm_source=gcom&utm_medium=home-franja-video-gplay&utm_campaign=aq-org_gcom_vitrine_low_perf_banner_web_tier1_reality_bbb23&utm_content=banner&utm_term=card3-franjavideo-bbb23
# Arquivo salvo em: pages/vitrine.globo.com#assine#bbb#origemId=91139#utm_source=gcom#utm_medium=home-franja-video-gplay#utm_campaign=aq-org_gcom_vitrine_low_perf_banner_web_tier1_reality_bbb23#utm_content=banner#utm_term=card3-franjavideo-bbb23.txt
# URL: https://ge.globo.com/futebol/times/palmeiras/noticia/2023/03/13/scarpa-ironiza-mensagem-de-willian-em-conversa-sobre-golpe-milionario-to-precisando-orar-mais.ghtml
# Arquivo salvo em: pages/ge.globo.com#futebol#times#palmeiras#noticia#2023#03#13#scarpa-ironiza-mensagem-de-willian-em-conversa-sobre-golpe-milionario-to-precisando-orar-mais.ghtml.txt
# URL: https://globoesporte.globo.com/futebol/times/sao-paulo/
# Arquivo salvo em: pages/globoesporte.globo.com#futebol#times#sao-paulo#.txt
# URL: https://gshow.globo.com/?utm_source=globo.com&utm_medium=header
# Arquivo salvo em: pages/gshow.globo.com##utm_source=globo.com#utm_medium=header.txt
# URL: https://revistaquem.globo.com/capas/
# Arquivo salvo em: pages/revistaquem.globo.com#capas#.txt
# URL: https://receitas.globo.com/tipos-de-prato/saladas/
# Arquivo salvo em: pages/receitas.globo.com#tipos-de-prato#saladas#.txt
# URL: http://app.globoesporte.globo.com/futebol/publico-no-brasil/time/fortaleza/
# Arquivo salvo em: pages/app.globoesporte.globo.com#futebol#publico-no-brasil#time#fortaleza#.txt
# URL: http://especiais.g1.globo.com/app-g1/
# Arquivo salvo em: pages/especiais.g1.globo.com#app-g1#.txt
# URL: https://globoplay.globo.com/canais/modo-viagem/
# Arquivo salvo em: pages/globoplay.globo.com#canais#modo-viagem#.txt
# URL: https://interativos.globoesporte.globo.com/comerciais/
# Arquivo salvo em: pages/interativos.globoesporte.globo.com#comerciais#.txt
# URL: https://valorinveste.globo.com/produtos/renda-fixa/noticia/2023/03/13/quem-rende-mais-tesouro-selic-nuconta-picpay-mercado-pago-ou-fundos-de-renda-fixa.ghtml
# Arquivo salvo em: pages/valorinveste.globo.com#produtos#renda-fixa#noticia#2023#03#13#quem-rende-mais-tesouro-selic-nuconta-picpay-mercado-pago-ou-fundos-de-renda-fixa.ghtml.txt
# URL: https://autoesporte.globo.com/carros/usados-e-seminovos/
# Arquivo salvo em: pages/autoesporte.globo.com#carros#usados-e-seminovos#.txt
# URL: https://www.techtudo.com.br/softwares/apps/redes-sociais/
# Arquivo salvo em: pages/www.techtudo.com.br#softwares#apps#redes-sociais#.txt
# URL: https://revistagalileu.globo.com/ciencia/espaco/
# Arquivo salvo em: pages/revistagalileu.globo.com#ciencia#espaco#.txt
# URL: https://extra.globo.com/horoscopo/
# Arquivo salvo em: pages/extra.globo.com#horoscopo#.txt
# URL: https://epocanegocios.globo.com/um-so-planeta/
# Arquivo salvo em: pages/epocanegocios.globo.com#um-so-planeta#.txt
# URL: https://revistacasaejardim.globo.com/tecnologia/casa-conectada/
# Arquivo salvo em: pages/revistacasaejardim.globo.com#tecnologia#casa-conectada#.txt
# URL: https://revistapegn.globo.com/startups/
# Arquivo salvo em: pages/revistapegn.globo.com#startups#.txt
# URL: https://revistacrescer.globo.com/tentantes/reproducao-assistida/
# Arquivo salvo em: pages/revistacrescer.globo.com#tentantes#reproducao-assistida#.txt
# URL: https://globorural.globo.com/agricultura/arroz/
# Arquivo salvo em: pages/globorural.globo.com#agricultura#arroz#.txt
# URL: https://radioglobo.globo.com/texto/2023/02/16/PAULA-DO-BBB-23-DIZ-QUE-LUISA-SONZA-A-FAZ-DUVIDAR-DE-SUA-SEXUALIDADE.htm
# Arquivo salvo em: pages/radioglobo.globo.com#texto#2023#02#16#PAULA-DO-BBB-23-DIZ-QUE-LUISA-SONZA-A-FAZ-DUVIDAR-DE-SUA-SEXUALIDADE.htm.txt
# URL: https://bhfm.globo.com/termo-de-uso/TERMO-DE-USO.htm
# Arquivo salvo em: pages/bhfm.globo.com#termo-de-uso#TERMO-DE-USO.htm.txt
# URL: https://casavogue.globo.com/interiores/decor-do-dia/
# Arquivo salvo em: pages/casavogue.globo.com#interiores#decor-do-dia#.txt
# URL: https://revistamarieclaire.globo.com/moda/
# Arquivo salvo em: pages/revistamarieclaire.globo.com#moda#.txt
# URL: https://umsoplaneta.globo.com/sociedade/
# Arquivo salvo em: pages/umsoplaneta.globo.com#sociedade#.txt
# URL: https://revistaglamour.globo.com/termos-de-uso
# Arquivo salvo em: pages/revistaglamour.globo.com#termos-de-uso.txt
# URL: http://redeglobo.globo.com/programacao.html
# Arquivo salvo em: pages/redeglobo.globo.com#programacao.html.txt
# URL: https://gq.globo.com/lifestyle/design/
# Arquivo salvo em: pages/gq.globo.com#lifestyle#design#.txt
# URL: https://revistamonet.globo.com/filmes/
# Arquivo salvo em: pages/revistamonet.globo.com#filmes#.txt
# URL: https://forum.techtudo.globo.com/usuarios/124569/ipar712
# Arquivo salvo em: pages/forum.techtudo.globo.com#usuarios#124569#ipar712.txt
# URL: https://vogue.globo.com/moda/tendencia/
# Arquivo salvo em: pages/vogue.globo.com#moda#tendencia#.txt
# URL: https://memoriaglobo.globo.com/jornalismo/jornalismo-e-telejornais/globo-rural/
# Arquivo salvo em: pages/memoriaglobo.globo.com#jornalismo#jornalismo-e-telejornais#globo-rural#.txt
# URL: https://historia.globo.com/memoria-roberto-marinho/noticia/memoria-roberto-marinho-lanca-especial-cem-bibliofilos-do-brasil.ghtml
# Arquivo salvo em: pages/historia.globo.com#memoria-roberto-marinho#noticia#memoria-roberto-marinho-lanca-especial-cem-bibliofilos-do-brasil.ghtml.txt
# URL: https://www.telecineplay.com.br/premiacoes-de-cinema
# Arquivo salvo em: pages/www.telecineplay.com.br#premiacoes-de-cinema.txt
# URL: http://vidadebicho.globo.com/colunistas/caoportamento
# Arquivo salvo em: pages/vidadebicho.globo.com#colunistas#caoportamento.txt
# URL: http://grupoglobo.globo.com/#inicio
# Arquivo salvo em: pages/grupoglobo.globo.com##inicio.txt
# URL: https://glamour.globo.com/
# Arquivo salvo em: pages/glamour.globo.com#.txt
# URL: https://www.climatempo.com.br/brasil
# Arquivo salvo em: pages/www.climatempo.com.br#brasil.txt
# URL: https://estuda.com
# Arquivo salvo em: pages/estuda.com.txt
# URL: https://globofilmes.globo.com/filmografia/comedia-romantica/filme/ta-escrito.ghtml
# Arquivo salvo em: pages/globofilmes.globo.com#filmografia#comedia-romantica#filme#ta-escrito.ghtml.txt
# URL: https://revistagloborural.globo.com/
# Arquivo salvo em: pages/revistagloborural.globo.com#.txt
# URL: https://canaisglobo.globo.com/c/bis/
# Arquivo salvo em: pages/canaisglobo.globo.com#c#bis#.txt
# URL: https://www.valor.com.br/international/
# Arquivo salvo em: pages/www.valor.com.br#international#.txt
# URL: https://www.publicidadeeditoraglobo.com.br/galileu/
# Arquivo salvo em: pages/www.publicidadeeditoraglobo.com.br#galileu#.txt
# URL: https://combate.globo.com/assine?origemId=226
# Arquivo salvo em: pages/combate.globo.com#assine#origemId=226.txt
# URL: https://canaloff.globo.com/futebol/times
# Arquivo salvo em: pages/canaloff.globo.com#futebol#times.txt
# URL: https://cbn.globoradio.globo.com/institucional/historia/HISTORIA.htm
# Arquivo salvo em: pages/cbn.globoradio.globo.com#institucional#historia#HISTORIA.htm.txt
# URL: https://vempraglobo.g.globo/#pt-BR/sites/CX_4001
# Arquivo salvo em: pages/vempraglobo.g.globo##pt-BR#sites#CX_4001.txt
# Error: OrderedDict mutated during iteration
# URL: https://www.livup.com.br/
# Arquivo salvo em: pages/www.livup.com.br#.txt
# URL: https://www.lojadomecanico.com.br
# Arquivo salvo em: pages/www.lojadomecanico.com.br.txt
# URL: https://olist.com/
# Arquivo salvo em: pages/olist.com#.txt
# Error: OrderedDict mutated during iteration
# URL: https://www.nomadglobal.com
# Arquivo salvo em: pages/www.nomadglobal.com.txt
# Error: OrderedDict mutated during iteration
# URL: https://www.merama.io/
# Arquivo salvo em: pages/www.merama.io#.txt
# URL: https://www.buser.com.br/
# Arquivo salvo em: pages/www.buser.com.br#.txt
# URL: https://arena.im/mlp/worldcup
# Arquivo salvo em: pages/arena.im#mlp#worldcup.txt
# Error: OrderedDict mutated during iteration
# URL: https://www.alice.com.br/time-de-saude
# Arquivo salvo em: pages/www.alice.com.br#time-de-saude.txt
# URL: https://www.emcasa.com/
# Arquivo salvo em: pages/www.emcasa.com#.txt
# URL: https://www.orama.com.br
# Arquivo salvo em: pages/www.orama.com.br.txt
# URL: https://www.p1gg.com.br
# Arquivo salvo em: pages/www.p1gg.com.br.txt
# URL: https://petlove.com.br
# Arquivo salvo em: pages/petlove.com.br.txt
# Error: <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.polen.me'. (_ssl.c:992)>
# Error: OrderedDict mutated during iteration
# URL: https://prozeducacao.com.br/
# Arquivo salvo em: pages/prozeducacao.com.br#.txt
# URL: https://www.quintoandar.com.br/
# Arquivo salvo em: pages/www.quintoandar.com.br#.txt
# URL: https://galena.com/quem-somos/
# Arquivo salvo em: pages/galena.com#quem-somos#.txt
# URL: https://www.gabriel.com.br#content
# Arquivo salvo em: pages/www.gabriel.com.br#content.txt
# URL: https://www.stone.com.br
# Arquivo salvo em: pages/www.stone.com.br.txt
# URL: https://www.sooper.com.br
# Arquivo salvo em: pages/www.sooper.com.br.txt
# URL: https://zippi.com.br/
# Arquivo salvo em: pages/zippi.com.br#.txt
# Error: HTTPSConnectionPool(host='privacidade.globo.com', port=443): Max retries exceeded with url: /privacy-policy/ (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:992)')))
# URL: https://www.winnin.com
# Arquivo salvo em: pages/www.winnin.com.txt
# URL: https://www.gov.br/pt-br
# Arquivo salvo em: pages/www.gov.br#pt-br.txt
# URL: http://www.cnpq.br/pt-br/termos-de-uso#govbr-busca-input
# Arquivo salvo em: pages/www.cnpq.br#pt-br#termos-de-uso#govbr-busca-input.txt
# URL: https://www.uol.com.br/carros/tabela-fipe/
# Arquivo salvo em: pages/www.uol.com.br#carros#tabela-fipe#.txt
# URL: http://negocios8.redeglobo.com.br/Paginas/Midia-Kit.aspx
# Arquivo salvo em: pages/negocios8.redeglobo.com.br#Paginas#Midia-Kit.aspx.txt
# URL: https://revistagalileu.globo.com/ciencia/arqueologia/
# Arquivo salvo em: pages/revistagalileu.globo.com#ciencia#arqueologia#.txt
# URL: https://revistapegn.globo.com/mulheres-empreendedoras/
# Arquivo salvo em: pages/revistapegn.globo.com#mulheres-empreendedoras#.txt
# URL: https://revistacrescer.globo.com/tentantes/planejando-a-gravidez/
# Arquivo salvo em: pages/revistacrescer.globo.com#tentantes#planejando-a-gravidez#.txt
# URL: https://revistamarieclaire.globo.com/beleza/cabelo/
# Arquivo salvo em: pages/revistamarieclaire.globo.com#beleza#cabelo#.txt
# URL: https://redeglobo.globo.com/Responsabilidade-Social/
# Arquivo salvo em: pages/redeglobo.globo.com#Responsabilidade-Social#.txt
# URL: https://revistacasaejardim.globo.com/conteudo-de-marca/
# Arquivo salvo em: pages/revistacasaejardim.globo.com#conteudo-de-marca#.txt
# URL: https://revistagloborural.globo.com/Um-So-Planeta
# Arquivo salvo em: pages/revistagloborural.globo.com#Um-So-Planeta.txt

# %% [markdown]
# # Bibliografia
#
# Baeza-Yates, Ricardo; Ribeiro-Neto, Berthier. **Modern information retrieval: the concepts and technology behind search**. ACM Press, 2011.
#
# Batista, Natércia ; Brandão, Michele ; Pinheiro, Michele ; Dalip, Daniel ; Moro, Mirella . **[Dados de Múltiplas Fontes da Web: coleta, integração e pré-processamento](https://sol.sbc.org.br/livros/index.php/sbc/catalog/download/8/19/58-1?inline=1)**. Minicursos do XXIV Simpósio Brasileiro de Sistemas Multimídia e Web. 1ed.: Sociedade Brasileira de Computação, 2018, v. , p. 153-192.
